# %% [markdown]
# # Face Generation
#
# In this project, you'll define and train a DCGAN on a dataset of faces. Your goal is to get a generator network to generate *new* images of faces that look as realistic as possible!
#
# The project will be broken down into a series of tasks from **loading in data to defining and training adversarial networks**. At the end of the notebook, you'll be able to visualize the results of your trained Generator to see how it performs; your generated samples should look like fairly realistic faces with small amounts of noise.
#
# ### Get the Data
#
# You'll be using the [CelebFaces Attributes Dataset (CelebA)](http://mmlab.ie.cuhk.edu.hk/projects/CelebA.html) to train your adversarial networks.
#
# This dataset is more complex than the number datasets (like MNIST or SVHN) you've been working with, and so, you should prepare to define deeper networks and train them for a longer time to get good results. It is suggested that you utilize a GPU for training.
#
# ### Pre-processed Data
#
# Since the project's main focus is on building the GANs, we've done *some* of the pre-processing for you. Each of the CelebA images has been cropped to remove parts of the image that don't include a face, then resized down to 64x64x3 NumPy images. Some sample data is show below.
#
# <img src='assets/processed_face_data.png' width=60% />
#
# > If you are working locally, you can download this data [by clicking here](https://s3.amazonaws.com/video.udacity-data.com/topher/2018/November/5be7eb6f_processed-celeba-small/processed-celeba-small.zip)
#
# This is a zip file that you'll need to extract in the home directory of this notebook for further loading and processing. After extracting the data, you should be left with a directory of data `processed_celeba_small/`

# %%
# can comment out after executing
# !unzip processed_celeba_small.zip

# %%
data_dir = 'processed_celeba_small/'

"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
import pickle as pkl
import matplotlib.pyplot as plt
import numpy as np
import problem_unittests as tests
#import helper

# %matplotlib inline

# %% [markdown]
# ## Visualize the CelebA Data
#
# The [CelebA](http://mmlab.ie.cuhk.edu.hk/projects/CelebA.html) dataset contains over 200,000 celebrity images with annotations. Since you're going to be generating faces, you won't need the annotations, you'll only need the images. Note that these are color images with [3 color channels (RGB)](https://en.wikipedia.org/wiki/Channel_(digital_image)#RGB_Images) each.
#
# ### Pre-process and Load the Data
#
# Since the project's main focus is on building the GANs, we've done *some* of the pre-processing for you. Each of the CelebA images has been cropped to remove parts of the image that don't include a face, then resized down to 64x64x3 NumPy images. This *pre-processed* dataset is a smaller subset of the very large CelebA data.
#
# > There are a few other steps that you'll need to **transform** this data and create a **DataLoader**.
#
# #### Exercise: Complete the following `get_dataloader` function, such that it satisfies these requirements:
#
# * Your images should be square, Tensor images of size `image_size x image_size` in the x and y dimension.
# * Your function should return a DataLoader that shuffles and batches these Tensor images.
#
# #### ImageFolder
#
# To create a dataset given a directory of images, it's recommended that you use PyTorch's [ImageFolder](https://pytorch.org/docs/stable/torchvision/datasets.html#imagefolder) wrapper, with a root directory `processed_celeba_small/` and data transformation passed in.

# %%
# necessary imports
import torch
from torchvision import datasets
from torchvision import transforms

# %%
def get_dataloader(batch_size, image_size, data_dir='processed_celeba_small/'):
    """
    Batch the neural network data using DataLoader
    :param batch_size: The size of each batch; the number of images in a batch
    :param img_size: The square size of the image data (x, y)
    :param data_dir: Directory where image data is located
    :return: DataLoader with batched data
    """
    
    # TODO: Implement function and return a dataloader
    transform = transforms.Compose([transforms.Resize(image_size),transforms.ToTensor()])
    img = datasets.ImageFolder(root=data_dir, transform=transform)
    dataloader = torch.utils.data.DataLoader(img, batch_size=batch_size, shuffle=True)
    
    return dataloader

# %% [markdown]
# ## Create a DataLoader
#
# #### Exercise: Create a DataLoader `celeba_train_loader` with appropriate hyperparameters.
#
# Call the above function and create a dataloader to view images.
# * You can decide on any reasonable `batch_size` parameter
# * Your `image_size` **must be** `32`. Resizing the data to a smaller size will make for faster training, while still creating convincing images of faces!

# %%
# Define function hyperparameters
batch_size = 64
img_size = 32

"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
# Call your function and get a dataloader
celeba_train_loader = get_dataloader(batch_size, img_size)

# %% [markdown]
# Next, you can view some images! You should seen square images of somewhat-centered faces.
#
# Note: You'll need to convert the Tensor images into a NumPy type and transpose the dimensions to correctly display an image, suggested `imshow` code is below, but it may not be perfect.

# %%
# swap color axis because
# numpy image: H x W x C
# torch image: C X H X W

# helper display function
def imshow(img):
    npimg = img.numpy()
    plt.imshow(np.transpose(npimg, (1, 2, 0)))

"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
# obtain one batch of training images
dataiter = iter(celeba_train_loader)
images, _ = dataiter.next() # _ for no labels

# plot the images in the batch, along with the corresponding labels
fig = plt.figure(figsize=(20, 4))
plot_size=20
for idx in np.arange(plot_size):
    ax = fig.add_subplot(2, plot_size/2, idx+1, xticks=[], yticks=[])
    imshow(images[idx])

# %% [markdown]
# #### Exercise: Pre-process your image data and scale it to a pixel range of -1 to 1
#
# You need to do a bit of pre-processing; you know that the output of a `tanh` activated generator will contain pixel values in a range from -1 to 1, and so, we need to rescale our training images to a range of -1 to 1. (Right now, they are in a range from 0-1.)

# %%
# TODO: Complete the scale function
def scale(x, feature_range=(-1, 1)):
    ''' Scale takes in an image x and returns that image, scaled
       with a feature_range of pixel values from -1 to 1. 
       This function assumes that the input x is already scaled from 0-1.'''
    # assume x is scaled to (0, 1)
    # scale to feature_range and return scaled x
    min, max = feature_range
    x = x * (max - min) + min
    return x

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
# check scaled range
# should be close to -1 to 1
img = images[0]
scaled_img = scale(img)

print('Min: ', scaled_img.min())
print('Max: ', scaled_img.max())

# %% [markdown]
# ---
# # Define the Model
#
# A GAN is comprised of two adversarial networks, a discriminator and a generator.
#
# ## Discriminator
#
# Your first task will be to define the discriminator. This is a convolutional classifier like you've built before, only without any maxpooling layers. To deal with this complex data, it's suggested you use a deep network with **normalization**. You are also allowed to create any helper functions that may be useful.
#
# #### Exercise: Complete the Discriminator class
# * The inputs to the discriminator are 32x32x3 tensor images
# * The output should be a single value that will indicate whether a given image is real or fake

# %%
import torch.nn as nn
import torch.nn.functional as F

# helper conv function
def conv(in_channels, out_channels, kernel_size, stride=2, padding=1, batch_norm=True):
    
    layers = []
    conv_layer = nn.Conv2d(in_channels, out_channels, 
                           kernel_size, stride, padding, bias=False)
    layers.append(conv_layer)
    
    if batch_norm:
        # append batchnorm layer
        layers.append(nn.BatchNorm2d(out_channels))
    
    return nn.Sequential(*layers)

# %%
class Discriminator(nn.Module):

    def __init__(self, conv_dim):
        """
        Initialize the Discriminator Module
        :param conv_dim: The depth of the first convolutional layer
        """
        
        super(Discriminator, self).__init__()

        # complete init function
        self.conv_dim = conv_dim
        # 32x32 initial
        self.conv1 = conv(3, conv_dim, 4, batch_norm=False)
        # 16x16 out
        
        self.conv2 = conv(conv_dim, conv_dim*2, 4)
        # 8x8 out
        
        self.conv3 = conv(conv_dim*2, conv_dim*4, 4)
        # 4x4 out
        
        # final, fully-connected layer
        self.fc = nn.Linear(conv_dim*4*4*4, 1)
        

    def forward(self, x):
        """
        Forward propagation of the neural network
        :param x: The input to the neural network     
        :return: Discriminator logits; the output of the neural network
        """
        # define feedforward behavior
        out = F.leaky_relu(self.conv1(x), 0.2)
        out = F.leaky_relu(self.conv2(out), 0.2)
        out = F.leaky_relu(self.conv3(out), 0.2)
        
        # flatten
        out = out.view(-1, self.conv_dim*4*4*4)
        
        # final output layer
        out = self.fc(out)
        return out


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_discriminator(Discriminator)
# Out:
# Tests Passed

# %% [markdown]
# ## Generator
#
# The generator should upsample an input and generate a *new* image of the same size as our training data `32x32x3`. This should be mostly transpose convolutional layers with normalization applied to the outputs.
#
# #### Exercise: Complete the Generator class
# * The inputs to the generator are vectors of some length `z_size`
# * The output should be a image of shape `32x32x3`

# %%
# helper conv function
def deconv(in_channels, out_channels, kernel_size, stride=2, padding=1, batch_norm=True):
    
    # create a sequence of transpose + optional batch norm layers
    layers = []
    transpose_conv_layer = nn.ConvTranspose2d(in_channels, out_channels, 
                                              kernel_size, stride, padding, bias=False)
    # append transpose convolutional layer
    layers.append(transpose_conv_layer)
    
    if batch_norm:
        # append batchnorm layer
        layers.append(nn.BatchNorm2d(out_channels))
        
    return nn.Sequential(*layers)

# %%
class Generator(nn.Module):
    
    def __init__(self, z_size, conv_dim):
        """
        Initialize the Generator Module
        :param z_size: The length of the input latent vector, z
        :param conv_dim: The depth of the inputs to the *last* transpose convolutional layer
        """
        super(Generator, self).__init__()

        # complete init function
        self.conv_dim = conv_dim
        
        # first, fully-connected layer
        self.fc = nn.Linear(z_size, conv_dim*4*4*4)

        # transpose conv layers
        self.t_conv1 = deconv(conv_dim*4, conv_dim*2, 4)
        self.t_conv2 = deconv(conv_dim*2, conv_dim, 4)
        self.t_conv3 = deconv(conv_dim, 3, 4, batch_norm=False)

    def forward(self, x):
        """
        Forward propagation of the neural network
        :param x: The input to the neural network     
        :return: A 32x32x3 Tensor image as output
        """
        # define feedforward behavior
        out = self.fc(x)
        out = out.view(-1, self.conv_dim*4, 4, 4) # (batch_size, depth, 4, 4)
        
        # hidden transpose conv layers + relu
        out = F.relu(self.t_conv1(out))
        out =F.relu(self.t_conv2(out))
        # last layer + tanh activation
        out = self.t_conv3(out)
        out = F.tanh(out)
        
        return out

"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_generator(Generator)
# Out:
# Tests Passed

# %% [markdown]
# ## Initialize the weights of your networks
#
# To help your models converge, you should initialize the weights of the convolutional and linear layers in your model. From reading the [original DCGAN paper](https://arxiv.org/pdf/1511.06434.pdf), they say:
# > All weights were initialized from a zero-centered Normal distribution with standard deviation 0.02.
#
# So, your next task will be to define a weight initialization function that does just this!
#
# You can refer back to the lesson on weight initialization or even consult existing model code, such as that from [the `networks.py` file in CycleGAN Github repository](https://github.com/junyanz/pytorch-CycleGAN-and-pix2pix/blob/master/models/networks.py) to help you complete this function.
#
# #### Exercise: Complete the weight initialization function
#
# * This should initialize only **convolutional** and **linear** layers
# * Initialize the weights to a normal distribution, centered around 0, with a standard deviation of 0.02.
# * The bias terms, if they exist, may be left alone or set to 0.

# %%
def weights_init_normal(m):
    """
    Applies initial weights to certain layers in a model .
    The weights are taken from a normal distribution 
    with mean = 0, std dev = 0.02.
    :param m: A module or layer in a network    
    """
    # classname will be something like:
    # `Conv`, `BatchNorm2d`, `Linear`, etc.
    classname = m.__class__.__name__
    
    # TODO: Apply initial weights to convolutional and linear layers
    if hasattr(m, 'weight') and (classname.find('Conv') != -1 or classname.find('Linear') != -1):
        nn.init.normal_(m.weight.data, 0.0, 0.02)
        if hasattr(m.bias, 'data'):
            nn.init.constant_(m.bias.data, 0.0)

# %% [markdown]
# ## Build complete network
#
# Define your models' hyperparameters and instantiate the discriminator and generator from the classes defined above. Make sure you've passed in the correct input arguments.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
def build_network(d_conv_dim, g_conv_dim, z_size):
    # define discriminator and generator
    D = Discriminator(d_conv_dim)
    G = Generator(z_size=z_size, conv_dim=g_conv_dim)

    # initialize model weights
    D.apply(weights_init_normal)
    G.apply(weights_init_normal)

    print(D)
    print()
    print(G)
    
    return D, G

# %% [markdown]
# #### Exercise: Define model hyperparameters

# %%
# Define model hyperparams
d_conv_dim = 32
g_conv_dim = 32
z_size = 100

"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
D, G = build_network(d_conv_dim, g_conv_dim, z_size)
# Out:
# Discriminator(
#   (conv1): Sequential(
#     (0): Conv2d(3, 32, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#   )
#   (conv2): Sequential(
#     (0): Conv2d(32, 64, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#     (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   )
#   (conv3): Sequential(
#     (0): Conv2d(64, 128, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#     (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   )
#   (fc): Linear(in_features=2048, out_features=1, bias=True)
# )
#
# Generator(
#   (fc): Linear(in_features=100, out_features=2048, bias=True)
#   (t_conv1): Sequential(
#     (0): ConvTranspose2d(128, 64, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#     (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   )
#   (t_conv2): Sequential(
#     (0): ConvTranspose2d(64, 32, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#     (1): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   )
#   (t_conv3): Sequential(
#     (0): ConvTranspose2d(32, 3, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#   )
# )

# %% [markdown]
# ### Training on GPU
#
# Check if you can train on GPU. Here, we'll set this as a boolean variable `train_on_gpu`. Later, you'll be responsible for making sure that
# >* Models,
# * Model inputs, and
# * Loss function arguments
#
# Are moved to GPU, where appropriate.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
import torch

# Check for a GPU
train_on_gpu = torch.cuda.is_available()
if not train_on_gpu:
    print('No GPU found. Please use a GPU to train your neural network.')
else:
    print('Training on GPU!')
# Out:
# Training on GPU!

# %% [markdown]
# ---
# ## Discriminator and Generator Losses
#
# Now we need to calculate the losses for both types of adversarial networks.
#
# ### Discriminator Losses
#
# > * For the discriminator, the total loss is the sum of the losses for real and fake images, `d_loss = d_real_loss + d_fake_loss`.
# * Remember that we want the discriminator to output 1 for real images and 0 for fake images, so we need to set up the losses to reflect that.
#
#
# ### Generator Loss
#
# The generator loss will look similar only with flipped labels. The generator's goal is to get the discriminator to *think* its generated images are *real*.
#
# #### Exercise: Complete real and fake loss functions
#
# **You may choose to use either cross entropy or a least squares error loss to complete the following `real_loss` and `fake_loss` functions.**

# %%
def real_loss(D_out, smooth=False):
    '''Calculates how close discriminator outputs are to being real.
       param, D_out: discriminator logits
       return: real loss'''
    batch_size = D_out.size(0)
    # label smoothing
    if smooth:
        # smooth, real labels = 0.9
        labels = torch.ones(batch_size)*0.9
    else:
        labels = torch.ones(batch_size) # real labels = 1
    # move labels to GPU if available     
    if train_on_gpu:
        labels = labels.cuda()
    # binary cross entropy with logits loss
    criterion = nn.BCEWithLogitsLoss()
    # calculate loss
    loss = criterion(D_out.squeeze(), labels)
    return loss


def fake_loss(D_out):
    '''Calculates how close discriminator outputs are to being fake.
       param, D_out: discriminator logits
       return: fake loss'''
    batch_size = D_out.size(0)
    labels = torch.zeros(batch_size) # fake labels = 0
    if train_on_gpu:
        labels = labels.cuda()
    criterion = nn.BCEWithLogitsLoss()
    # calculate loss
    loss = criterion(D_out.squeeze(), labels)
    return loss

# %% [markdown]
# ## Optimizers
#
# #### Exercise: Define optimizers for your Discriminator (D) and Generator (G)
#
# Define optimizers for your models with appropriate hyperparameters.

# %%
import torch.optim as optim

lr = 0.0002
beta1=0.5
beta2=0.999

# Create optimizers for the discriminator D and generator G
d_optimizer = optim.Adam(D.parameters(), lr,[beta1, beta2])
g_optimizer = optim.Adam(G.parameters(), lr,[beta1, beta2])

# %% [markdown]
# ---
# ## Training
#
# Training will involve alternating between training the discriminator and the generator. You'll use your functions `real_loss` and `fake_loss` to help you calculate the discriminator losses.
#
# * You should train the discriminator by alternating on real and fake images
# * Then the generator, which tries to trick the discriminator and should have an opposing loss function
#
#
# #### Saving Samples
#
# You've been given some code to print out some loss statistics and save some generated "fake" samples.

# %% [markdown]
# #### Exercise: Complete the training function
#
# Keep in mind that, if you've moved your models to GPU, you'll also have to move any model inputs to GPU.

# %%
def train(D, G, n_epochs, print_every=50):
    '''Trains adversarial networks for some number of epochs
       param, D: the discriminator network
       param, G: the generator network
       param, n_epochs: number of epochs to train for
       param, print_every: when to print and record the models' losses
       return: D and G losses'''
    
    # move models to GPU
    if train_on_gpu:
        D.cuda()
        G.cuda()

    # keep track of loss and generated, "fake" samples
    samples = []
    losses = []

    # Get some fixed data for sampling. These are images that are held
    # constant throughout training, and allow us to inspect the model's performance
    sample_size=16
    fixed_z = np.random.uniform(-1, 1, size=(sample_size, z_size))
    fixed_z = torch.from_numpy(fixed_z).float()
    # move z to GPU if available
    if train_on_gpu:
        fixed_z = fixed_z.cuda()

    # epoch training loop
    for epoch in range(n_epochs):

        # batch training loop
        for batch_i, (real_images, _) in enumerate(celeba_train_loader):

            batch_size = real_images.size(0)
            real_images = scale(real_images)

            # ===============================================
            #         YOUR CODE HERE: TRAIN THE NETWORKS
            # ===============================================
            
            d_optimizer.zero_grad()
            if train_on_gpu:
                real_images = real_images.cuda()
            
            # 1. Train the discriminator on real and fake images
            D_real = D(real_images)
            d_real_loss = real_loss(D_real)
            # Generate fake images
            z = np.random.uniform(-1, 1, size=(batch_size, z_size))
            z = torch.from_numpy(z).float()
            # move x to GPU, if available
            if train_on_gpu:
                z = z.cuda()
            fake_images = G(z)

            # Compute the discriminator losses on fake images            
            D_fake = D(fake_images)
            d_fake_loss = fake_loss(D_fake)

            # add up loss and perform backprop
            d_loss = d_real_loss + d_fake_loss
            d_loss.backward()
            d_optimizer.step() 
            
####################################################
####################################################

            # 2. Train the generator with an adversarial loss
            g_optimizer.zero_grad()
        
            # Generate fake images
            z = np.random.uniform(-1, 1, size=(batch_size, z_size))
            z = torch.from_numpy(z).float()
            if train_on_gpu:
                z = z.cuda()
            fake_images = G(z)

            # Compute the discriminator losses on fake images 
            # using flipped labels!
            D_fake = D(fake_images)
            g_loss = real_loss(D_fake) # use real loss to flip labels

            # perform backprop
            g_loss.backward()
            g_optimizer.step() 
            
            
            # ===============================================
            #              END OF YOUR CODE
            # ===============================================

            # Print some loss stats
            if batch_i % print_every == 0:
                # append discriminator loss and generator loss
                losses.append((d_loss.item(), g_loss.item()))
                # print discriminator and generator loss
                print('Epoch [{:5d}/{:5d}] | d_loss: {:6.4f} | g_loss: {:6.4f}'.format(
                        epoch+1, n_epochs, d_loss.item(), g_loss.item()))


        ## AFTER EACH EPOCH##    
        # this code assumes your generator is named G, feel free to change the name
        # generate and save sample, fake images
        G.eval() # for generating samples
        samples_z = G(fixed_z)
        samples.append(samples_z)
        G.train() # back to training mode

    # Save training generator samples
    with open('train_samples.pkl', 'wb') as f:
        pkl.dump(samples, f)
    
    # finally return losses
    return losses

# %% [markdown]
# Set your number of training epochs and train your GAN!

# %%
# set number of epochs 
n_epochs = 50


"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
# call training function
losses = train(D, G, n_epochs=n_epochs)
# Out:
# Epoch [    1/   50] | d_loss: 1.3214 | g_loss: 0.9019
# Epoch [    1/   50] | d_loss: 0.2060 | g_loss: 2.7851
# Epoch [    1/   50] | d_loss: 0.0925 | g_loss: 4.2860
# Epoch [    1/   50] | d_loss: 0.1097 | g_loss: 3.4170
# Epoch [    1/   50] | d_loss: 0.1641 | g_loss: 2.5062
# Epoch [    1/   50] | d_loss: 0.2629 | g_loss: 1.4777
# Epoch [    1/   50] | d_loss: 0.3085 | g_loss: 3.2719
# Epoch [    1/   50] | d_loss: 0.4141 | g_loss: 2.5804
# Epoch [    1/   50] | d_loss: 0.5128 | g_loss: 2.0125
# Epoch [    1/   50] | d_loss: 0.5893 | g_loss: 3.2989
# Epoch [    1/   50] | d_loss: 0.6487 | g_loss: 2.1716
# Epoch [    1/   50] | d_loss: 0.7550 | g_loss: 1.5955
# Epoch [    1/   50] | d_loss: 1.1577 | g_loss: 0.8459
# Epoch [    1/   50] | d_loss: 0.9648 | g_loss: 2.2440
# Epoch [    1/   50] | d_loss: 1.3862 | g_loss: 2.2348
# Epoch [    1/   50] | d_loss: 1.2943 | g_loss: 0.9197
# Epoch [    1/   50] | d_loss: 0.8922 | g_loss: 1.2269
# Epoch [    1/   50] | d_loss: 0.9890 | g_loss: 1.3042
# Epoch [    1/   50] | d_loss: 1.2928 | g_loss: 0.7443
# Epoch [    1/   50] | d_loss: 1.0813 | g_loss: 0.9306
# Epoch [    1/   50] | d_loss: 1.0579 | g_loss: 1.0660
# Epoch [    1/   50] | d_loss: 1.1163 | g_loss: 1.2888
# Epoch [    1/   50] | d_loss: 1.0308 | g_loss: 1.3776
# Epoch [    1/   50] | d_loss: 1.0680 | g_loss: 1.2311
# Epoch [    1/   50] | d_loss: 1.3526 | g_loss: 0.4638
# Epoch [    1/   50] | d_loss: 1.0196 | g_loss: 0.7586
# Epoch [    1/   50] | d_loss: 1.1641 | g_loss: 0.8940
# Epoch [    1/   50] | d_loss: 1.0652 | g_loss: 0.7282
# Epoch [    1/   50] | d_loss: 1.0122 | g_loss: 1.2921
# Epoch [    2/   50] | d_loss: 1.1398 | g_loss: 1.3688
# Epoch [    2/   50] | d_loss: 1.1934 | g_loss: 0.4265
# Epoch [    2/   50] | d_loss: 1.1197 | g_loss: 1.4971
# Epoch [    2/   50] | d_loss: 1.0672 | g_loss: 0.8184
# Epoch [    2/   50] | d_loss: 0.9892 | g_loss: 1.2774
# Epoch [    2/   50] | d_loss: 1.3006 | g_loss: 0.8534
# Epoch [    2/   50] | d_loss: 1.0894 | g_loss: 1.8018
# Epoch [    2/   50] | d_loss: 1.0242 | g_loss: 1.0865
# Epoch [    2/   50] | d_loss: 0.9499 | g_loss: 1.3324
# Epoch [    2/   50] | d_loss: 1.0936 | g_loss: 1.1274
# Epoch [    2/   50] | d_loss: 1.0247 | g_loss: 1.1549
# Epoch [    2/   50] | d_loss: 1.3147 | g_loss: 0.7789
# Epoch [    2/   50] | d_loss: 1.0790 | g_loss: 0.9607
# Epoch [    2/   50] | d_loss: 1.0142 | g_loss: 0.9744
# Epoch [    2/   50] | d_loss: 1.2401 | g_loss: 0.9338
# Epoch [    2/   50] | d_loss: 0.8897 | g_loss: 1.2191
# Epoch [    2/   50] | d_loss: 1.0777 | g_loss: 1.2184
# Epoch [    2/   50] | d_loss: 1.0368 | g_loss: 1.0361
# Epoch [    2/   50] | d_loss: 1.0261 | g_loss: 1.6355
# Epoch [    2/   50] | d_loss: 1.1411 | g_loss: 1.0864
# Epoch [    2/   50] | d_loss: 1.1527 | g_loss: 0.8392
# Epoch [    2/   50] | d_loss: 1.2881 | g_loss: 1.3170
# Epoch [    2/   50] | d_loss: 0.8739 | g_loss: 1.2143
# Epoch [    2/   50] | d_loss: 1.0600 | g_loss: 1.1737
# Epoch [    2/   50] | d_loss: 1.0257 | g_loss: 1.0102
# Epoch [    2/   50] | d_loss: 1.1105 | g_loss: 1.4513
# Epoch [    2/   50] | d_loss: 1.1701 | g_loss: 1.0287
# Epoch [    2/   50] | d_loss: 0.8586 | g_loss: 1.0174
# Epoch [    2/   50] | d_loss: 0.8924 | g_loss: 1.3449
# Epoch [    3/   50] | d_loss: 1.0752 | g_loss: 0.9597
# Epoch [    3/   50] | d_loss: 0.9898 | g_loss: 0.7832
# Epoch [    3/   50] | d_loss: 1.3988 | g_loss: 1.0414
# Epoch [    3/   50] | d_loss: 1.0403 | g_loss: 1.2682
# Epoch [    3/   50] | d_loss: 1.1402 | g_loss: 1.0137
# Epoch [    3/   50] | d_loss: 0.9772 | g_loss: 1.1227
# Epoch [    3/   50] | d_loss: 1.1690 | g_loss: 1.1991
# Epoch [    3/   50] | d_loss: 1.1037 | g_loss: 1.5940
# Epoch [    3/   50] | d_loss: 1.3143 | g_loss: 0.6992
# Epoch [    3/   50] | d_loss: 1.0011 | g_loss: 0.9964
# Epoch [    3/   50] | d_loss: 1.0329 | g_loss: 1.0833
# Epoch [    3/   50] | d_loss: 1.0557 | g_loss: 1.2010
# Epoch [    3/   50] | d_loss: 1.1981 | g_loss: 1.2532
# Epoch [    3/   50] | d_loss: 1.0414 | g_loss: 1.1706
# Epoch [    3/   50] | d_loss: 1.0830 | g_loss: 1.1390
# Epoch [    3/   50] | d_loss: 1.0076 | g_loss: 1.1497
# Epoch [    3/   50] | d_loss: 1.1509 | g_loss: 1.6819
# Epoch [    3/   50] | d_loss: 1.0231 | g_loss: 1.4340
# Epoch [    3/   50] | d_loss: 1.0848 | g_loss: 1.2620
# Epoch [    3/   50] | d_loss: 0.9852 | g_loss: 1.5926
# Epoch [    3/   50] | d_loss: 0.9699 | g_loss: 1.2956
# Epoch [    3/   50] | d_loss: 0.7989 | g_loss: 1.0548
# Epoch [    3/   50] | d_loss: 1.1282 | g_loss: 0.6951
# Epoch [    3/   50] | d_loss: 0.9182 | g_loss: 1.5834
# Epoch [    3/   50] | d_loss: 1.0362 | g_loss: 1.0944
# Epoch [    3/   50] | d_loss: 1.2027 | g_loss: 1.6378
# Epoch [    3/   50] | d_loss: 1.0694 | g_loss: 1.0791
# Epoch [    3/   50] | d_loss: 1.4115 | g_loss: 0.8827
# Epoch [    3/   50] | d_loss: 0.8188 | g_loss: 1.2704
# Epoch [    4/   50] | d_loss: 0.9897 | g_loss: 1.4188
# Epoch [    4/   50] | d_loss: 0.8345 | g_loss: 0.8199
# Epoch [    4/   50] | d_loss: 1.1824 | g_loss: 1.0531
# Epoch [    4/   50] | d_loss: 1.2907 | g_loss: 0.9887
# Epoch [    4/   50] | d_loss: 1.1345 | g_loss: 1.4015
# Epoch [    4/   50] | d_loss: 1.1691 | g_loss: 1.2268
# Epoch [    4/   50] | d_loss: 1.0643 | g_loss: 0.8018
# Epoch [    4/   50] | d_loss: 0.8905 | g_loss: 1.3780
# Epoch [    4/   50] | d_loss: 0.9626 | g_loss: 1.1339
# Epoch [    4/   50] | d_loss: 0.8775 | g_loss: 1.4907
# Epoch [    4/   50] | d_loss: 1.1117 | g_loss: 0.8004
# Epoch [    4/   50] | d_loss: 1.0703 | g_loss: 0.8053
# Epoch [    4/   50] | d_loss: 1.3210 | g_loss: 1.0907
# Epoch [    4/   50] | d_loss: 1.0683 | g_loss: 1.1056
# Epoch [    4/   50] | d_loss: 1.0450 | g_loss: 1.0645
# Epoch [    4/   50] | d_loss: 0.8797 | g_loss: 1.2215
# Epoch [    4/   50] | d_loss: 0.9149 | g_loss: 1.7398
# Epoch [    4/   50] | d_loss: 1.0568 | g_loss: 1.5438
# Epoch [    4/   50] | d_loss: 1.0013 | g_loss: 0.8094
# Epoch [    4/   50] | d_loss: 0.7889 | g_loss: 1.1067
# Epoch [    4/   50] | d_loss: 0.9451 | g_loss: 1.4487
# Epoch [    4/   50] | d_loss: 0.9152 | g_loss: 1.7433
# Epoch [    4/   50] | d_loss: 1.3433 | g_loss: 0.5799
# Epoch [    4/   50] | d_loss: 0.9695 | g_loss: 1.1329
# Epoch [    4/   50] | d_loss: 1.0792 | g_loss: 1.2584
# Epoch [    4/   50] | d_loss: 0.9713 | g_loss: 1.0356
# Epoch [    4/   50] | d_loss: 0.9298 | g_loss: 1.1014
# Epoch [    4/   50] | d_loss: 0.8861 | g_loss: 1.0205
# Epoch [    4/   50] | d_loss: 1.1317 | g_loss: 0.8691
# Epoch [    5/   50] | d_loss: 1.5001 | g_loss: 0.6427
# Epoch [    5/   50] | d_loss: 1.0206 | g_loss: 1.1038
# Epoch [    5/   50] | d_loss: 0.8854 | g_loss: 1.6210
# Epoch [    5/   50] | d_loss: 0.8961 | g_loss: 1.2590
# Epoch [    5/   50] | d_loss: 1.2178 | g_loss: 0.9361
# Epoch [    5/   50] | d_loss: 0.6680 | g_loss: 2.1204
# Epoch [    5/   50] | d_loss: 0.8665 | g_loss: 1.1699
# Epoch [    5/   50] | d_loss: 0.9369 | g_loss: 1.4306
# Epoch [    5/   50] | d_loss: 0.9482 | g_loss: 0.8614
# Epoch [    5/   50] | d_loss: 1.0672 | g_loss: 2.1532
# Epoch [    5/   50] | d_loss: 0.7804 | g_loss: 1.4328
# Epoch [    5/   50] | d_loss: 1.2113 | g_loss: 0.3165
# Epoch [    5/   50] | d_loss: 0.9153 | g_loss: 1.2649
# Epoch [    5/   50] | d_loss: 0.9542 | g_loss: 1.5102
# Epoch [    5/   50] | d_loss: 0.9712 | g_loss: 1.5715
# Epoch [    5/   50] | d_loss: 0.7951 | g_loss: 1.2128
# Epoch [    5/   50] | d_loss: 1.0552 | g_loss: 0.5010
# Epoch [    5/   50] | d_loss: 1.1915 | g_loss: 0.5489
# Epoch [    5/   50] | d_loss: 1.0083 | g_loss: 1.2915
# Epoch [    5/   50] | d_loss: 1.1878 | g_loss: 1.3860
# Epoch [    5/   50] | d_loss: 0.9256 | g_loss: 1.2820
# Epoch [    5/   50] | d_loss: 1.0068 | g_loss: 1.5098
# Epoch [    5/   50] | d_loss: 0.8426 | g_loss: 0.9444
# Epoch [    5/   50] | d_loss: 0.9080 | g_loss: 0.9836
# Epoch [    5/   50] | d_loss: 1.0134 | g_loss: 1.5742
# Epoch [    5/   50] | d_loss: 0.8687 | g_loss: 1.5610
# Epoch [    5/   50] | d_loss: 1.2889 | g_loss: 1.8855
# Epoch [    5/   50] | d_loss: 0.9066 | g_loss: 1.3703
# Epoch [    5/   50] | d_loss: 0.9023 | g_loss: 0.9596
# Epoch [    6/   50] | d_loss: 1.4702 | g_loss: 2.2632
# Epoch [    6/   50] | d_loss: 0.8899 | g_loss: 0.9606
# Epoch [    6/   50] | d_loss: 0.9790 | g_loss: 1.0337
# Epoch [    6/   50] | d_loss: 0.9357 | g_loss: 1.5611
# Epoch [    6/   50] | d_loss: 0.8945 | g_loss: 1.1216
# Epoch [    6/   50] | d_loss: 0.9053 | g_loss: 1.3427
# Epoch [    6/   50] | d_loss: 0.9997 | g_loss: 1.0516
# Epoch [    6/   50] | d_loss: 1.0847 | g_loss: 0.8273
# Epoch [    6/   50] | d_loss: 0.8354 | g_loss: 1.5465
# Epoch [    6/   50] | d_loss: 0.7105 | g_loss: 1.4659
# Epoch [    6/   50] | d_loss: 1.0669 | g_loss: 1.9143
# Epoch [    6/   50] | d_loss: 1.3481 | g_loss: 2.0414
# Epoch [    6/   50] | d_loss: 1.0138 | g_loss: 2.2317
# Epoch [    6/   50] | d_loss: 0.9260 | g_loss: 1.5208
# Epoch [    6/   50] | d_loss: 1.1712 | g_loss: 1.6320
# Epoch [    6/   50] | d_loss: 1.2417 | g_loss: 0.6052
# Epoch [    6/   50] | d_loss: 0.9386 | g_loss: 0.9766
# Epoch [    6/   50] | d_loss: 0.9082 | g_loss: 1.0763
# Epoch [    6/   50] | d_loss: 0.9612 | g_loss: 1.6757
# Epoch [    6/   50] | d_loss: 1.0370 | g_loss: 0.7605
# Epoch [    6/   50] | d_loss: 1.1967 | g_loss: 0.6816
# Epoch [    6/   50] | d_loss: 1.0393 | g_loss: 1.1434
# Epoch [    6/   50] | d_loss: 0.8349 | g_loss: 1.3448
# Epoch [    6/   50] | d_loss: 0.8321 | g_loss: 0.9813
# Epoch [    6/   50] | d_loss: 1.3959 | g_loss: 1.4420
# Epoch [    6/   50] | d_loss: 0.7954 | g_loss: 1.7810
# Epoch [    6/   50] | d_loss: 1.0986 | g_loss: 0.6774
# Epoch [    6/   50] | d_loss: 1.0426 | g_loss: 2.0599
# Epoch [    6/   50] | d_loss: 0.7215 | g_loss: 1.6746
# Epoch [    7/   50] | d_loss: 1.2415 | g_loss: 1.9712
# Epoch [    7/   50] | d_loss: 0.8436 | g_loss: 0.8270
# Epoch [    7/   50] | d_loss: 0.9938 | g_loss: 0.9277
# Epoch [    7/   50] | d_loss: 1.1237 | g_loss: 1.5172
# Epoch [    7/   50] | d_loss: 1.0217 | g_loss: 0.9657
# Epoch [    7/   50] | d_loss: 1.0392 | g_loss: 0.6518
# Epoch [    7/   50] | d_loss: 0.8960 | g_loss: 0.8813
# Epoch [    7/   50] | d_loss: 1.2526 | g_loss: 1.1521
# Epoch [    7/   50] | d_loss: 0.6450 | g_loss: 1.6015
# Epoch [    7/   50] | d_loss: 1.3400 | g_loss: 0.2770
# Epoch [    7/   50] | d_loss: 0.9713 | g_loss: 1.3044
# Epoch [    7/   50] | d_loss: 0.9977 | g_loss: 1.1582
# Epoch [    7/   50] | d_loss: 0.6572 | g_loss: 1.1875
# Epoch [    7/   50] | d_loss: 0.6764 | g_loss: 1.7914
# Epoch [    7/   50] | d_loss: 1.0841 | g_loss: 1.2005
# Epoch [    7/   50] | d_loss: 0.9823 | g_loss: 1.1117
# Epoch [    7/   50] | d_loss: 0.8417 | g_loss: 1.4351
# Epoch [    7/   50] | d_loss: 0.8718 | g_loss: 1.2918
# Epoch [    7/   50] | d_loss: 0.8343 | g_loss: 1.7448
# Epoch [    7/   50] | d_loss: 0.7678 | g_loss: 1.7544
# Epoch [    7/   50] | d_loss: 0.6455 | g_loss: 2.0229
# Epoch [    7/   50] | d_loss: 1.0493 | g_loss: 1.5135
# Epoch [    7/   50] | d_loss: 1.1778 | g_loss: 2.1965
# Epoch [    7/   50] | d_loss: 1.0103 | g_loss: 0.9288
# Epoch [    7/   50] | d_loss: 0.9073 | g_loss: 0.9151
# Epoch [    7/   50] | d_loss: 0.8379 | g_loss: 1.3536
# Epoch [    7/   50] | d_loss: 1.0024 | g_loss: 1.8800
# Epoch [    7/   50] | d_loss: 0.9629 | g_loss: 1.0153
# Epoch [    7/   50] | d_loss: 1.0116 | g_loss: 1.3593
# Epoch [    8/   50] | d_loss: 1.2483 | g_loss: 2.5402
# Epoch [    8/   50] | d_loss: 0.7547 | g_loss: 1.5991
# Epoch [    8/   50] | d_loss: 0.7141 | g_loss: 1.9789
# Epoch [    8/   50] | d_loss: 1.0336 | g_loss: 1.2311
# Epoch [    8/   50] | d_loss: 0.8501 | g_loss: 1.2954
# Epoch [    8/   50] | d_loss: 0.8214 | g_loss: 0.8560
# Epoch [    8/   50] | d_loss: 0.9351 | g_loss: 1.9498
# Epoch [    8/   50] | d_loss: 1.1194 | g_loss: 1.8585
# Epoch [    8/   50] | d_loss: 0.8198 | g_loss: 1.6826
# Epoch [    8/   50] | d_loss: 1.0961 | g_loss: 1.9991
# Epoch [    8/   50] | d_loss: 0.9086 | g_loss: 1.0592
# Epoch [    8/   50] | d_loss: 0.9652 | g_loss: 1.1952
# Epoch [    8/   50] | d_loss: 1.4984 | g_loss: 2.2335
# Epoch [    8/   50] | d_loss: 0.9003 | g_loss: 1.1748
# Epoch [    8/   50] | d_loss: 1.0875 | g_loss: 2.1838
# Epoch [    8/   50] | d_loss: 1.1632 | g_loss: 0.7255
# Epoch [    8/   50] | d_loss: 0.9027 | g_loss: 1.1537
# Epoch [    8/   50] | d_loss: 0.9789 | g_loss: 0.8152
# Epoch [    8/   50] | d_loss: 1.0671 | g_loss: 0.6618
# Epoch [    8/   50] | d_loss: 0.9346 | g_loss: 1.1955
# Epoch [    8/   50] | d_loss: 1.0014 | g_loss: 0.7128
# Epoch [    8/   50] | d_loss: 0.9895 | g_loss: 0.9639
# Epoch [    8/   50] | d_loss: 1.0200 | g_loss: 1.7141
# Epoch [    8/   50] | d_loss: 0.8423 | g_loss: 1.2868
# Epoch [    8/   50] | d_loss: 1.9299 | g_loss: 2.0539
# Epoch [    8/   50] | d_loss: 0.7788 | g_loss: 1.0121
# Epoch [    8/   50] | d_loss: 0.9435 | g_loss: 1.7624
# Epoch [    8/   50] | d_loss: 0.7502 | g_loss: 1.4871
# Epoch [    8/   50] | d_loss: 0.8357 | g_loss: 2.1500
# Epoch [    9/   50] | d_loss: 1.5794 | g_loss: 2.3210
# Epoch [    9/   50] | d_loss: 0.8515 | g_loss: 1.3665
# Epoch [    9/   50] | d_loss: 0.7856 | g_loss: 0.9877
# Epoch [    9/   50] | d_loss: 0.7946 | g_loss: 1.3001
# Epoch [    9/   50] | d_loss: 0.9755 | g_loss: 1.0259
# Epoch [    9/   50] | d_loss: 0.9235 | g_loss: 2.4378
# Epoch [    9/   50] | d_loss: 1.4034 | g_loss: 1.6940
# Epoch [    9/   50] | d_loss: 0.8820 | g_loss: 0.8900
# Epoch [    9/   50] | d_loss: 0.6087 | g_loss: 1.4283
# Epoch [    9/   50] | d_loss: 0.7416 | g_loss: 1.5394
# Epoch [    9/   50] | d_loss: 0.6152 | g_loss: 1.6184
# Epoch [    9/   50] | d_loss: 0.6501 | g_loss: 1.6436
# Epoch [    9/   50] | d_loss: 0.8016 | g_loss: 1.8601
# Epoch [    9/   50] | d_loss: 0.7957 | g_loss: 1.0622
# Epoch [    9/   50] | d_loss: 0.7838 | g_loss: 1.3147
# Epoch [    9/   50] | d_loss: 0.8299 | g_loss: 1.2325
# Epoch [    9/   50] | d_loss: 1.2509 | g_loss: 1.7355
# Epoch [    9/   50] | d_loss: 0.7971 | g_loss: 1.2801
# Epoch [    9/   50] | d_loss: 0.8023 | g_loss: 1.1405
# Epoch [    9/   50] | d_loss: 1.6061 | g_loss: 2.6955
# Epoch [    9/   50] | d_loss: 0.6371 | g_loss: 1.6270
# Epoch [    9/   50] | d_loss: 0.9814 | g_loss: 2.6286
# Epoch [    9/   50] | d_loss: 0.9624 | g_loss: 0.9179
# Epoch [    9/   50] | d_loss: 0.9609 | g_loss: 1.0307
# Epoch [    9/   50] | d_loss: 0.8572 | g_loss: 1.5316
# Epoch [    9/   50] | d_loss: 0.8324 | g_loss: 1.2570
# Epoch [    9/   50] | d_loss: 0.7601 | g_loss: 1.4200
# Epoch [    9/   50] | d_loss: 1.0281 | g_loss: 0.7896
# Epoch [    9/   50] | d_loss: 0.7661 | g_loss: 2.0561
# Epoch [   10/   50] | d_loss: 0.7980 | g_loss: 0.7395
# Epoch [   10/   50] | d_loss: 0.4758 | g_loss: 2.8072
# Epoch [   10/   50] | d_loss: 0.9387 | g_loss: 2.1196
# Epoch [   10/   50] | d_loss: 0.8486 | g_loss: 1.3695
# Epoch [   10/   50] | d_loss: 0.6800 | g_loss: 1.6882
# Epoch [   10/   50] | d_loss: 0.7331 | g_loss: 1.7089
# Epoch [   10/   50] | d_loss: 0.8401 | g_loss: 0.9119
# Epoch [   10/   50] | d_loss: 0.6104 | g_loss: 0.9911
# Epoch [   10/   50] | d_loss: 0.8462 | g_loss: 1.4182
# Epoch [   10/   50] | d_loss: 0.6816 | g_loss: 1.7945
# Epoch [   10/   50] | d_loss: 1.0590 | g_loss: 0.7683
# Epoch [   10/   50] | d_loss: 0.8877 | g_loss: 2.2189
# Epoch [   10/   50] | d_loss: 1.1945 | g_loss: 0.1587
# Epoch [   10/   50] | d_loss: 0.8839 | g_loss: 1.8645
# Epoch [   10/   50] | d_loss: 0.7127 | g_loss: 1.9578
# Epoch [   10/   50] | d_loss: 0.6920 | g_loss: 1.5138
# Epoch [   10/   50] | d_loss: 0.6646 | g_loss: 1.3708
# Epoch [   10/   50] | d_loss: 1.0422 | g_loss: 0.7694
# Epoch [   10/   50] | d_loss: 0.6906 | g_loss: 1.5099
# Epoch [   10/   50] | d_loss: 0.6899 | g_loss: 1.6565
# Epoch [   10/   50] | d_loss: 1.0974 | g_loss: 0.9348
# Epoch [   10/   50] | d_loss: 0.7077 | g_loss: 1.6719
# Epoch [   10/   50] | d_loss: 0.7219 | g_loss: 1.9024
# Epoch [   10/   50] | d_loss: 0.6464 | g_loss: 1.9335
# Epoch [   10/   50] | d_loss: 0.7251 | g_loss: 1.4768
# Epoch [   10/   50] | d_loss: 0.7978 | g_loss: 1.6122
# Epoch [   10/   50] | d_loss: 0.7288 | g_loss: 1.4110
# Epoch [   10/   50] | d_loss: 0.7665 | g_loss: 0.6638
# Epoch [   10/   50] | d_loss: 1.0890 | g_loss: 2.9799
# Epoch [   11/   50] | d_loss: 1.0615 | g_loss: 1.1743
# Epoch [   11/   50] | d_loss: 1.1929 | g_loss: 2.8372
# Epoch [   11/   50] | d_loss: 0.8278 | g_loss: 1.3868
# Epoch [   11/   50] | d_loss: 0.9359 | g_loss: 1.4105
# Epoch [   11/   50] | d_loss: 0.7039 | g_loss: 1.4311
# Epoch [   11/   50] | d_loss: 0.7278 | g_loss: 2.2490
# Epoch [   11/   50] | d_loss: 0.7361 | g_loss: 2.4930
# Epoch [   11/   50] | d_loss: 0.9781 | g_loss: 2.1563
# Epoch [   11/   50] | d_loss: 0.8488 | g_loss: 1.4294
# Epoch [   11/   50] | d_loss: 0.6973 | g_loss: 2.2448
# Epoch [   11/   50] | d_loss: 0.8637 | g_loss: 1.6705
# Epoch [   11/   50] | d_loss: 1.1778 | g_loss: 0.4967
# Epoch [   11/   50] | d_loss: 0.7834 | g_loss: 1.5928
# Epoch [   11/   50] | d_loss: 0.8746 | g_loss: 2.2789
# Epoch [   11/   50] | d_loss: 0.4975 | g_loss: 1.6993
# Epoch [   11/   50] | d_loss: 0.7797 | g_loss: 2.1256
# Epoch [   11/   50] | d_loss: 0.7878 | g_loss: 1.7541
# Epoch [   11/   50] | d_loss: 0.6839 | g_loss: 1.9362
# Epoch [   11/   50] | d_loss: 0.8421 | g_loss: 1.1623
# Epoch [   11/   50] | d_loss: 0.9620 | g_loss: 2.0522
# Epoch [   11/   50] | d_loss: 0.5950 | g_loss: 2.1685
# Epoch [   11/   50] | d_loss: 0.9644 | g_loss: 1.2669
# Epoch [   11/   50] | d_loss: 0.7049 | g_loss: 1.1850
# Epoch [   11/   50] | d_loss: 0.5803 | g_loss: 1.8585
# Epoch [   11/   50] | d_loss: 0.7677 | g_loss: 2.2408
# Epoch [   11/   50] | d_loss: 0.4875 | g_loss: 2.1436
# Epoch [   11/   50] | d_loss: 0.7400 | g_loss: 1.8850
# Epoch [   11/   50] | d_loss: 0.7215 | g_loss: 2.2294
# Epoch [   11/   50] | d_loss: 0.5606 | g_loss: 2.2096
# Epoch [   12/   50] | d_loss: 1.1542 | g_loss: 2.5707
# Epoch [   12/   50] | d_loss: 0.7263 | g_loss: 1.7921
# Epoch [   12/   50] | d_loss: 0.7972 | g_loss: 1.9786
# Epoch [   12/   50] | d_loss: 0.6889 | g_loss: 1.9536
# Epoch [   12/   50] | d_loss: 0.5759 | g_loss: 1.7232
# Epoch [   12/   50] | d_loss: 1.0265 | g_loss: 1.2721
# Epoch [   12/   50] | d_loss: 1.1189 | g_loss: 2.1583
# Epoch [   12/   50] | d_loss: 0.9344 | g_loss: 1.3134
# Epoch [   12/   50] | d_loss: 0.7108 | g_loss: 1.6420
# Epoch [   12/   50] | d_loss: 0.6510 | g_loss: 1.9185
# Epoch [   12/   50] | d_loss: 0.7643 | g_loss: 2.6233
# Epoch [   12/   50] | d_loss: 0.8084 | g_loss: 2.1483
# Epoch [   12/   50] | d_loss: 0.7220 | g_loss: 2.1921
# Epoch [   12/   50] | d_loss: 0.9053 | g_loss: 0.8678
# Epoch [   12/   50] | d_loss: 0.8950 | g_loss: 0.8108
# Epoch [   12/   50] | d_loss: 0.5839 | g_loss: 1.4813
# Epoch [   12/   50] | d_loss: 0.7659 | g_loss: 1.7398
# Epoch [   12/   50] | d_loss: 0.8315 | g_loss: 1.6126
# Epoch [   12/   50] | d_loss: 0.6056 | g_loss: 2.7071
# Epoch [   12/   50] | d_loss: 0.8190 | g_loss: 1.5542
# Epoch [   12/   50] | d_loss: 0.6721 | g_loss: 1.5691
# Epoch [   12/   50] | d_loss: 0.5873 | g_loss: 1.4249
# Epoch [   12/   50] | d_loss: 0.5211 | g_loss: 2.4631
# Epoch [   12/   50] | d_loss: 0.5403 | g_loss: 2.3300
# Epoch [   12/   50] | d_loss: 0.6503 | g_loss: 1.7077
# Epoch [   12/   50] | d_loss: 0.8746 | g_loss: 1.3139
# Epoch [   12/   50] | d_loss: 0.8921 | g_loss: 1.4588
# Epoch [   12/   50] | d_loss: 0.6885 | g_loss: 1.2989
# Epoch [   12/   50] | d_loss: 0.5577 | g_loss: 2.2871
# Epoch [   13/   50] | d_loss: 0.7334 | g_loss: 1.0296
# Epoch [   13/   50] | d_loss: 0.8261 | g_loss: 0.8983
# Epoch [   13/   50] | d_loss: 0.5784 | g_loss: 1.8627
# Epoch [   13/   50] | d_loss: 0.7237 | g_loss: 1.4145
# Epoch [   13/   50] | d_loss: 0.6947 | g_loss: 2.1692
# Epoch [   13/   50] | d_loss: 0.7794 | g_loss: 2.1398
# Epoch [   13/   50] | d_loss: 0.8530 | g_loss: 1.6118
# Epoch [   13/   50] | d_loss: 0.6336 | g_loss: 2.0252
# Epoch [   13/   50] | d_loss: 0.7258 | g_loss: 0.8542
# Epoch [   13/   50] | d_loss: 0.4566 | g_loss: 1.9784
# Epoch [   13/   50] | d_loss: 0.6176 | g_loss: 1.5497
# Epoch [   13/   50] | d_loss: 0.8157 | g_loss: 0.9827
# Epoch [   13/   50] | d_loss: 0.8364 | g_loss: 1.1521
# Epoch [   13/   50] | d_loss: 0.5788 | g_loss: 1.4141
# Epoch [   13/   50] | d_loss: 0.8184 | g_loss: 1.9316
# Epoch [   13/   50] | d_loss: 0.5685 | g_loss: 1.4776
# Epoch [   13/   50] | d_loss: 0.4769 | g_loss: 1.7148
# Epoch [   13/   50] | d_loss: 0.6491 | g_loss: 2.2017
# Epoch [   13/   50] | d_loss: 1.5766 | g_loss: 5.3020
# Epoch [   13/   50] | d_loss: 0.4736 | g_loss: 2.1111
# Epoch [   13/   50] | d_loss: 0.7459 | g_loss: 2.5184
# Epoch [   13/   50] | d_loss: 0.7157 | g_loss: 1.1595
# Epoch [   13/   50] | d_loss: 0.5828 | g_loss: 2.0750
# Epoch [   13/   50] | d_loss: 0.5441 | g_loss: 1.3619
# Epoch [   13/   50] | d_loss: 0.4757 | g_loss: 1.8874
# Epoch [   13/   50] | d_loss: 0.8233 | g_loss: 1.2594
# Epoch [   13/   50] | d_loss: 0.6406 | g_loss: 1.5723
# Epoch [   13/   50] | d_loss: 0.5062 | g_loss: 1.5354
# Epoch [   13/   50] | d_loss: 0.5993 | g_loss: 2.1300
# Epoch [   14/   50] | d_loss: 0.6897 | g_loss: 1.6168
# Epoch [   14/   50] | d_loss: 0.6894 | g_loss: 2.4661
# Epoch [   14/   50] | d_loss: 0.5446 | g_loss: 1.5134
# Epoch [   14/   50] | d_loss: 0.7041 | g_loss: 1.7464
# Epoch [   14/   50] | d_loss: 0.5985 | g_loss: 1.8629
# Epoch [   14/   50] | d_loss: 0.5399 | g_loss: 2.6958
# Epoch [   14/   50] | d_loss: 0.6064 | g_loss: 1.7925
# Epoch [   14/   50] | d_loss: 0.8709 | g_loss: 1.2176
# Epoch [   14/   50] | d_loss: 0.5876 | g_loss: 1.5544
# Epoch [   14/   50] | d_loss: 0.6320 | g_loss: 3.0391
# Epoch [   14/   50] | d_loss: 0.5815 | g_loss: 1.5816
# Epoch [   14/   50] | d_loss: 0.5944 | g_loss: 1.2356
# Epoch [   14/   50] | d_loss: 0.5506 | g_loss: 1.3123
# Epoch [   14/   50] | d_loss: 0.6712 | g_loss: 1.6842
# Epoch [   14/   50] | d_loss: 0.4446 | g_loss: 1.9854
# Epoch [   14/   50] | d_loss: 0.6537 | g_loss: 2.4704
# Epoch [   14/   50] | d_loss: 0.6946 | g_loss: 0.9131
# Epoch [   14/   50] | d_loss: 0.9826 | g_loss: 1.0199
# Epoch [   14/   50] | d_loss: 0.7428 | g_loss: 1.0692
# Epoch [   14/   50] | d_loss: 0.6775 | g_loss: 2.0359
# Epoch [   14/   50] | d_loss: 0.4996 | g_loss: 1.7800
# Epoch [   14/   50] | d_loss: 0.7478 | g_loss: 1.0326
# Epoch [   14/   50] | d_loss: 0.6660 | g_loss: 1.7212
# Epoch [   14/   50] | d_loss: 0.5054 | g_loss: 1.1545
# Epoch [   14/   50] | d_loss: 0.7143 | g_loss: 0.9031
# Epoch [   14/   50] | d_loss: 0.6879 | g_loss: 0.9982
# Epoch [   14/   50] | d_loss: 0.7233 | g_loss: 1.7507
# Epoch [   14/   50] | d_loss: 0.5589 | g_loss: 2.1153
# Epoch [   14/   50] | d_loss: 0.5768 | g_loss: 1.6578
# Epoch [   15/   50] | d_loss: 0.4669 | g_loss: 1.5075
# Epoch [   15/   50] | d_loss: 0.7000 | g_loss: 1.4082
# Epoch [   15/   50] | d_loss: 0.8053 | g_loss: 1.6914
# Epoch [   15/   50] | d_loss: 0.9020 | g_loss: 1.1220
# Epoch [   15/   50] | d_loss: 0.6715 | g_loss: 2.6681
# Epoch [   15/   50] | d_loss: 0.5160 | g_loss: 0.9591
# Epoch [   15/   50] | d_loss: 0.5338 | g_loss: 2.0097
# Epoch [   15/   50] | d_loss: 0.5457 | g_loss: 2.2093
# Epoch [   15/   50] | d_loss: 0.5078 | g_loss: 1.8585
# Epoch [   15/   50] | d_loss: 0.6178 | g_loss: 1.4282
# Epoch [   15/   50] | d_loss: 0.5252 | g_loss: 1.6293
# Epoch [   15/   50] | d_loss: 0.3121 | g_loss: 3.4618
# Epoch [   15/   50] | d_loss: 0.5060 | g_loss: 2.1435
# Epoch [   15/   50] | d_loss: 0.5256 | g_loss: 1.2021
# Epoch [   15/   50] | d_loss: 0.5192 | g_loss: 1.8729
# Epoch [   15/   50] | d_loss: 0.6075 | g_loss: 1.2118
# Epoch [   15/   50] | d_loss: 0.6567 | g_loss: 1.6915
# Epoch [   15/   50] | d_loss: 1.0759 | g_loss: 3.7516
# Epoch [   15/   50] | d_loss: 0.5894 | g_loss: 2.3122
# Epoch [   15/   50] | d_loss: 0.6805 | g_loss: 1.8733
# Epoch [   15/   50] | d_loss: 0.5105 | g_loss: 2.2049
# Epoch [   15/   50] | d_loss: 0.5917 | g_loss: 1.8918
# Epoch [   15/   50] | d_loss: 0.4764 | g_loss: 1.6030
# Epoch [   15/   50] | d_loss: 0.6889 | g_loss: 1.3676
# Epoch [   15/   50] | d_loss: 0.3426 | g_loss: 2.4964
# Epoch [   15/   50] | d_loss: 0.6384 | g_loss: 1.7617
# Epoch [   15/   50] | d_loss: 0.5239 | g_loss: 3.1637
# Epoch [   15/   50] | d_loss: 0.4657 | g_loss: 2.8234
# Epoch [   15/   50] | d_loss: 0.4164 | g_loss: 1.6427
# Epoch [   16/   50] | d_loss: 1.0504 | g_loss: 3.4918
# Epoch [   16/   50] | d_loss: 0.5958 | g_loss: 2.1548
# Epoch [   16/   50] | d_loss: 0.9103 | g_loss: 2.6538
# Epoch [   16/   50] | d_loss: 0.5258 | g_loss: 1.8249
# Epoch [   16/   50] | d_loss: 0.9713 | g_loss: 2.5694
# Epoch [   16/   50] | d_loss: 0.5757 | g_loss: 1.5635
# Epoch [   16/   50] | d_loss: 0.7369 | g_loss: 1.7476
# Epoch [   16/   50] | d_loss: 0.4309 | g_loss: 1.5895
# Epoch [   16/   50] | d_loss: 1.2561 | g_loss: 4.7140
# Epoch [   16/   50] | d_loss: 0.9811 | g_loss: 3.6196
# Epoch [   16/   50] | d_loss: 0.4425 | g_loss: 1.8258
# Epoch [   16/   50] | d_loss: 0.6353 | g_loss: 2.0846
# Epoch [   16/   50] | d_loss: 0.4981 | g_loss: 2.3998
# Epoch [   16/   50] | d_loss: 0.4501 | g_loss: 1.5730
# Epoch [   16/   50] | d_loss: 0.9498 | g_loss: 1.2818
# Epoch [   16/   50] | d_loss: 0.5997 | g_loss: 2.1251
# Epoch [   16/   50] | d_loss: 0.3900 | g_loss: 2.9472
# Epoch [   16/   50] | d_loss: 0.6214 | g_loss: 2.5882
# Epoch [   16/   50] | d_loss: 0.3380 | g_loss: 2.6191
# Epoch [   16/   50] | d_loss: 0.5553 | g_loss: 2.2889
# Epoch [   16/   50] | d_loss: 0.4540 | g_loss: 2.3801
# Epoch [   16/   50] | d_loss: 0.2785 | g_loss: 2.6488
# Epoch [   16/   50] | d_loss: 0.2942 | g_loss: 2.3315
# Epoch [   16/   50] | d_loss: 0.4904 | g_loss: 2.1620
# Epoch [   16/   50] | d_loss: 0.7429 | g_loss: 3.4293
# Epoch [   16/   50] | d_loss: 0.3530 | g_loss: 1.7650
# Epoch [   16/   50] | d_loss: 0.6052 | g_loss: 2.8172
# Epoch [   16/   50] | d_loss: 0.5567 | g_loss: 1.1890
# Epoch [   16/   50] | d_loss: 0.4460 | g_loss: 2.2746
# Epoch [   17/   50] | d_loss: 0.3771 | g_loss: 2.7577
# Epoch [   17/   50] | d_loss: 0.9056 | g_loss: 1.3163
# Epoch [   17/   50] | d_loss: 0.5080 | g_loss: 2.7877
# Epoch [   17/   50] | d_loss: 0.4583 | g_loss: 2.7490
# Epoch [   17/   50] | d_loss: 0.4615 | g_loss: 2.7909
# Epoch [   17/   50] | d_loss: 0.2516 | g_loss: 3.6255
# Epoch [   17/   50] | d_loss: 0.3454 | g_loss: 2.2382
# Epoch [   17/   50] | d_loss: 0.4254 | g_loss: 2.2388
# Epoch [   17/   50] | d_loss: 0.6639 | g_loss: 2.2067
# Epoch [   17/   50] | d_loss: 0.6438 | g_loss: 2.6572
# Epoch [   17/   50] | d_loss: 0.5047 | g_loss: 1.5860
# Epoch [   17/   50] | d_loss: 0.3276 | g_loss: 2.1499
# Epoch [   17/   50] | d_loss: 0.5604 | g_loss: 2.3794
# Epoch [   17/   50] | d_loss: 0.6851 | g_loss: 2.9530
# Epoch [   17/   50] | d_loss: 0.4204 | g_loss: 3.2978
# Epoch [   17/   50] | d_loss: 0.5459 | g_loss: 3.0990
# Epoch [   17/   50] | d_loss: 0.3268 | g_loss: 3.0112
# Epoch [   17/   50] | d_loss: 0.5938 | g_loss: 3.1477
# Epoch [   17/   50] | d_loss: 1.3623 | g_loss: 0.7300
# Epoch [   17/   50] | d_loss: 0.5102 | g_loss: 2.1388
# Epoch [   17/   50] | d_loss: 0.4113 | g_loss: 2.4494
# Epoch [   17/   50] | d_loss: 0.5189 | g_loss: 2.8098
# Epoch [   17/   50] | d_loss: 0.3837 | g_loss: 2.7741
# Epoch [   17/   50] | d_loss: 0.7682 | g_loss: 3.4944
# Epoch [   17/   50] | d_loss: 0.6371 | g_loss: 2.9152
# Epoch [   17/   50] | d_loss: 0.8964 | g_loss: 2.1043
# Epoch [   17/   50] | d_loss: 0.3944 | g_loss: 2.3472
# Epoch [   17/   50] | d_loss: 0.6030 | g_loss: 1.7208
# Epoch [   17/   50] | d_loss: 0.5197 | g_loss: 1.7012
# Epoch [   18/   50] | d_loss: 0.7533 | g_loss: 1.4213
# Epoch [   18/   50] | d_loss: 0.4321 | g_loss: 2.1689
# Epoch [   18/   50] | d_loss: 0.4543 | g_loss: 1.9722
# Epoch [   18/   50] | d_loss: 0.4293 | g_loss: 1.8852
# Epoch [   18/   50] | d_loss: 0.5063 | g_loss: 2.9651
# Epoch [   18/   50] | d_loss: 0.4838 | g_loss: 2.9271
# Epoch [   18/   50] | d_loss: 0.4656 | g_loss: 2.2802
# Epoch [   18/   50] | d_loss: 0.3786 | g_loss: 2.1392
# Epoch [   18/   50] | d_loss: 0.2761 | g_loss: 2.2824
# Epoch [   18/   50] | d_loss: 0.5585 | g_loss: 2.2241
# Epoch [   18/   50] | d_loss: 0.3663 | g_loss: 2.7364
# Epoch [   18/   50] | d_loss: 0.5527 | g_loss: 1.7805
# Epoch [   18/   50] | d_loss: 0.4444 | g_loss: 2.5114
# Epoch [   18/   50] | d_loss: 0.6800 | g_loss: 2.4753
# Epoch [   18/   50] | d_loss: 0.6023 | g_loss: 2.7921
# Epoch [   18/   50] | d_loss: 0.7940 | g_loss: 2.0039
# Epoch [   18/   50] | d_loss: 0.5923 | g_loss: 2.9380
# Epoch [   18/   50] | d_loss: 0.6037 | g_loss: 2.7679
# Epoch [   18/   50] | d_loss: 0.3431 | g_loss: 2.2125
# Epoch [   18/   50] | d_loss: 0.6099 | g_loss: 1.9504
# Epoch [   18/   50] | d_loss: 0.6854 | g_loss: 1.3486
# Epoch [   18/   50] | d_loss: 0.4927 | g_loss: 3.1297
# Epoch [   18/   50] | d_loss: 0.6966 | g_loss: 1.5478
# Epoch [   18/   50] | d_loss: 0.5130 | g_loss: 2.6296
# Epoch [   18/   50] | d_loss: 0.3993 | g_loss: 2.3134
# Epoch [   18/   50] | d_loss: 0.7069 | g_loss: 2.3280
# Epoch [   18/   50] | d_loss: 0.9324 | g_loss: 3.0434
# Epoch [   18/   50] | d_loss: 0.3306 | g_loss: 1.7103
# Epoch [   18/   50] | d_loss: 0.5116 | g_loss: 1.1705
# Epoch [   19/   50] | d_loss: 0.4417 | g_loss: 2.4813
# Epoch [   19/   50] | d_loss: 0.4831 | g_loss: 2.6320
# Epoch [   19/   50] | d_loss: 0.7865 | g_loss: 3.6083
# Epoch [   19/   50] | d_loss: 0.2699 | g_loss: 2.3574
# Epoch [   19/   50] | d_loss: 1.0782 | g_loss: 1.2308
# Epoch [   19/   50] | d_loss: 0.3801 | g_loss: 2.3210
# Epoch [   19/   50] | d_loss: 0.5687 | g_loss: 2.3407
# Epoch [   19/   50] | d_loss: 0.6473 | g_loss: 1.2287
# Epoch [   19/   50] | d_loss: 0.8835 | g_loss: 2.0436
# Epoch [   19/   50] | d_loss: 0.3095 | g_loss: 2.8232
# Epoch [   19/   50] | d_loss: 0.2812 | g_loss: 2.9797
# Epoch [   19/   50] | d_loss: 0.4106 | g_loss: 2.1256
# Epoch [   19/   50] | d_loss: 0.4418 | g_loss: 2.6983
# Epoch [   19/   50] | d_loss: 0.5632 | g_loss: 1.3473
# Epoch [   19/   50] | d_loss: 1.0255 | g_loss: 4.2622
# Epoch [   19/   50] | d_loss: 0.6901 | g_loss: 1.8433
# Epoch [   19/   50] | d_loss: 0.3796 | g_loss: 2.5633
# Epoch [   19/   50] | d_loss: 0.4271 | g_loss: 1.9587
# Epoch [   19/   50] | d_loss: 0.5030 | g_loss: 3.9475
# Epoch [   19/   50] | d_loss: 0.4034 | g_loss: 2.6378
# Epoch [   19/   50] | d_loss: 0.2989 | g_loss: 3.0477
# Epoch [   19/   50] | d_loss: 0.4781 | g_loss: 2.2871
# Epoch [   19/   50] | d_loss: 0.5227 | g_loss: 1.7181
# Epoch [   19/   50] | d_loss: 0.4946 | g_loss: 2.8020
# Epoch [   19/   50] | d_loss: 0.4023 | g_loss: 1.3176
# Epoch [   19/   50] | d_loss: 0.7251 | g_loss: 1.1199
# Epoch [   19/   50] | d_loss: 0.2051 | g_loss: 3.0206
# Epoch [   19/   50] | d_loss: 0.2562 | g_loss: 3.2298
# Epoch [   19/   50] | d_loss: 0.3883 | g_loss: 1.3917
# Epoch [   20/   50] | d_loss: 0.5461 | g_loss: 2.0414
# Epoch [   20/   50] | d_loss: 0.3410 | g_loss: 1.9970
# Epoch [   20/   50] | d_loss: 0.6148 | g_loss: 1.0649
# Epoch [   20/   50] | d_loss: 0.4598 | g_loss: 3.2134
# Epoch [   20/   50] | d_loss: 0.2471 | g_loss: 2.4512
# Epoch [   20/   50] | d_loss: 0.4214 | g_loss: 2.5970
# Epoch [   20/   50] | d_loss: 0.7349 | g_loss: 1.8635
# Epoch [   20/   50] | d_loss: 0.3797 | g_loss: 1.9536
# Epoch [   20/   50] | d_loss: 0.3854 | g_loss: 2.3055
# Epoch [   20/   50] | d_loss: 0.6337 | g_loss: 2.4971
# Epoch [   20/   50] | d_loss: 1.3142 | g_loss: 4.6724
# Epoch [   20/   50] | d_loss: 0.4660 | g_loss: 1.5004
# Epoch [   20/   50] | d_loss: 0.3103 | g_loss: 2.2403
# Epoch [   20/   50] | d_loss: 0.4437 | g_loss: 2.0474
# Epoch [   20/   50] | d_loss: 0.3371 | g_loss: 2.4293
# Epoch [   20/   50] | d_loss: 0.4221 | g_loss: 2.5000
# Epoch [   20/   50] | d_loss: 1.0439 | g_loss: 1.6708
# Epoch [   20/   50] | d_loss: 0.3153 | g_loss: 2.0927
# Epoch [   20/   50] | d_loss: 0.3529 | g_loss: 1.9500
# Epoch [   20/   50] | d_loss: 0.3259 | g_loss: 2.3467
# Epoch [   20/   50] | d_loss: 0.2654 | g_loss: 2.2080
# Epoch [   20/   50] | d_loss: 0.4384 | g_loss: 2.9595
# Epoch [   20/   50] | d_loss: 0.3079 | g_loss: 2.9094
# Epoch [   20/   50] | d_loss: 0.5011 | g_loss: 2.7268
# Epoch [   20/   50] | d_loss: 0.7197 | g_loss: 2.2651
# Epoch [   20/   50] | d_loss: 0.5554 | g_loss: 3.6731
# Epoch [   20/   50] | d_loss: 0.3732 | g_loss: 3.5592
# Epoch [   20/   50] | d_loss: 0.3257 | g_loss: 2.8895
# Epoch [   20/   50] | d_loss: 0.8242 | g_loss: 3.3350
# Epoch [   21/   50] | d_loss: 0.3413 | g_loss: 3.0927
# Epoch [   21/   50] | d_loss: 0.4478 | g_loss: 2.2680
# Epoch [   21/   50] | d_loss: 0.3202 | g_loss: 2.2325
# Epoch [   21/   50] | d_loss: 6.0895 | g_loss: 4.8807
# Epoch [   21/   50] | d_loss: 0.5848 | g_loss: 2.7595
# Epoch [   21/   50] | d_loss: 0.4258 | g_loss: 2.6686
# Epoch [   21/   50] | d_loss: 0.4676 | g_loss: 1.9499
# Epoch [   21/   50] | d_loss: 0.4382 | g_loss: 2.8648
# Epoch [   21/   50] | d_loss: 0.3777 | g_loss: 2.4451
# Epoch [   21/   50] | d_loss: 0.5564 | g_loss: 2.9043
# Epoch [   21/   50] | d_loss: 0.3150 | g_loss: 2.1738
# Epoch [   21/   50] | d_loss: 0.7110 | g_loss: 3.0266
# Epoch [   21/   50] | d_loss: 0.2880 | g_loss: 3.7349
# Epoch [   21/   50] | d_loss: 0.3805 | g_loss: 2.5912
# Epoch [   21/   50] | d_loss: 0.4413 | g_loss: 2.2569
# Epoch [   21/   50] | d_loss: 0.4033 | g_loss: 2.9720
# Epoch [   21/   50] | d_loss: 0.3515 | g_loss: 3.2160
# Epoch [   21/   50] | d_loss: 0.5297 | g_loss: 2.0069
# Epoch [   21/   50] | d_loss: 0.3430 | g_loss: 1.6108
# Epoch [   21/   50] | d_loss: 0.6334 | g_loss: 0.7048
# Epoch [   21/   50] | d_loss: 0.4350 | g_loss: 2.9092
# Epoch [   21/   50] | d_loss: 0.5157 | g_loss: 1.1760
# Epoch [   21/   50] | d_loss: 0.4238 | g_loss: 2.1858
# Epoch [   21/   50] | d_loss: 0.4993 | g_loss: 2.4689
# Epoch [   21/   50] | d_loss: 0.5467 | g_loss: 3.1060
# Epoch [   21/   50] | d_loss: 0.3044 | g_loss: 2.7864
# Epoch [   21/   50] | d_loss: 0.3891 | g_loss: 2.5609
# Epoch [   21/   50] | d_loss: 0.8455 | g_loss: 3.1214
# Epoch [   21/   50] | d_loss: 0.5208 | g_loss: 1.8699
# Epoch [   22/   50] | d_loss: 0.5514 | g_loss: 3.3298
# Epoch [   22/   50] | d_loss: 0.2716 | g_loss: 2.1814
# Epoch [   22/   50] | d_loss: 0.3327 | g_loss: 2.7330
# Epoch [   22/   50] | d_loss: 0.3319 | g_loss: 3.2318
# Epoch [   22/   50] | d_loss: 0.3947 | g_loss: 2.3823
# Epoch [   22/   50] | d_loss: 0.4490 | g_loss: 2.7301
# Epoch [   22/   50] | d_loss: 0.4579 | g_loss: 1.9600
# Epoch [   22/   50] | d_loss: 0.2840 | g_loss: 3.1739
# Epoch [   22/   50] | d_loss: 0.3500 | g_loss: 3.6497
# Epoch [   22/   50] | d_loss: 0.3185 | g_loss: 3.1798
# Epoch [   22/   50] | d_loss: 0.2749 | g_loss: 2.5500
# Epoch [   22/   50] | d_loss: 0.2620 | g_loss: 2.7925
# Epoch [   22/   50] | d_loss: 0.4349 | g_loss: 2.0869
# Epoch [   22/   50] | d_loss: 0.3640 | g_loss: 3.1567
# Epoch [   22/   50] | d_loss: 0.2077 | g_loss: 2.0568
# Epoch [   22/   50] | d_loss: 0.3847 | g_loss: 2.5694
# Epoch [   22/   50] | d_loss: 0.3438 | g_loss: 2.1980
# Epoch [   22/   50] | d_loss: 0.7911 | g_loss: 3.1065
# Epoch [   22/   50] | d_loss: 0.3291 | g_loss: 1.7604
# Epoch [   22/   50] | d_loss: 0.4708 | g_loss: 1.3894
# Epoch [   22/   50] | d_loss: 0.4634 | g_loss: 2.2847
# Epoch [   22/   50] | d_loss: 0.4276 | g_loss: 2.7266
# Epoch [   22/   50] | d_loss: 0.5675 | g_loss: 2.5404
# Epoch [   22/   50] | d_loss: 0.7959 | g_loss: 4.7560
# Epoch [   22/   50] | d_loss: 0.3812 | g_loss: 2.7372
# Epoch [   22/   50] | d_loss: 0.3302 | g_loss: 2.7344
# Epoch [   22/   50] | d_loss: 0.3006 | g_loss: 2.1888
# Epoch [   22/   50] | d_loss: 0.2421 | g_loss: 2.7022
# Epoch [   22/   50] | d_loss: 0.3864 | g_loss: 3.8395
# Epoch [   23/   50] | d_loss: 0.4207 | g_loss: 2.2621
# Epoch [   23/   50] | d_loss: 0.2270 | g_loss: 2.7925
# Epoch [   23/   50] | d_loss: 0.4354 | g_loss: 2.2813
# Epoch [   23/   50] | d_loss: 0.2577 | g_loss: 1.8909
# Epoch [   23/   50] | d_loss: 0.4417 | g_loss: 2.4976
# Epoch [   23/   50] | d_loss: 0.2992 | g_loss: 2.9491
# Epoch [   23/   50] | d_loss: 0.3815 | g_loss: 2.0282
# Epoch [   23/   50] | d_loss: 0.6339 | g_loss: 3.0981
# Epoch [   23/   50] | d_loss: 0.3043 | g_loss: 2.9245
# Epoch [   23/   50] | d_loss: 3.2206 | g_loss: 1.3456
# Epoch [   23/   50] | d_loss: 0.3302 | g_loss: 1.9107
# Epoch [   23/   50] | d_loss: 0.3549 | g_loss: 2.9279
# Epoch [   23/   50] | d_loss: 0.5817 | g_loss: 1.4934
# Epoch [   23/   50] | d_loss: 0.7047 | g_loss: 0.8929
# Epoch [   23/   50] | d_loss: 0.4619 | g_loss: 2.3349
# Epoch [   23/   50] | d_loss: 0.2609 | g_loss: 2.9623
# Epoch [   23/   50] | d_loss: 0.2983 | g_loss: 2.7412
# Epoch [   23/   50] | d_loss: 0.2776 | g_loss: 3.3202
# Epoch [   23/   50] | d_loss: 0.9421 | g_loss: 1.2324
# Epoch [   23/   50] | d_loss: 0.4088 | g_loss: 2.6151
# Epoch [   23/   50] | d_loss: 0.3915 | g_loss: 1.9146
# Epoch [   23/   50] | d_loss: 0.4034 | g_loss: 2.8723
# Epoch [   23/   50] | d_loss: 0.3477 | g_loss: 3.4534
# Epoch [   23/   50] | d_loss: 0.2606 | g_loss: 3.0129
# Epoch [   23/   50] | d_loss: 0.6559 | g_loss: 3.2579
# Epoch [   23/   50] | d_loss: 0.6303 | g_loss: 2.3492
# Epoch [   23/   50] | d_loss: 0.4707 | g_loss: 2.4163
# Epoch [   23/   50] | d_loss: 0.3171 | g_loss: 2.9875
# Epoch [   23/   50] | d_loss: 0.3550 | g_loss: 2.8954
# Epoch [   24/   50] | d_loss: 0.2540 | g_loss: 3.2251
# Epoch [   24/   50] | d_loss: 0.5210 | g_loss: 3.0316
# Epoch [   24/   50] | d_loss: 0.4664 | g_loss: 2.0784
# Epoch [   24/   50] | d_loss: 0.2982 | g_loss: 3.7001
# Epoch [   24/   50] | d_loss: 0.3331 | g_loss: 2.5806
# Epoch [   24/   50] | d_loss: 0.3231 | g_loss: 3.4447
# Epoch [   24/   50] | d_loss: 0.3507 | g_loss: 3.0865
# Epoch [   24/   50] | d_loss: 0.3117 | g_loss: 2.2288
# Epoch [   24/   50] | d_loss: 0.4041 | g_loss: 1.9557
# Epoch [   24/   50] | d_loss: 0.3667 | g_loss: 2.4709
# Epoch [   24/   50] | d_loss: 0.4445 | g_loss: 2.6190
# Epoch [   24/   50] | d_loss: 0.3390 | g_loss: 2.8269
# Epoch [   24/   50] | d_loss: 0.6081 | g_loss: 2.1003
# Epoch [   24/   50] | d_loss: 0.3657 | g_loss: 2.7733
# Epoch [   24/   50] | d_loss: 0.3427 | g_loss: 1.8307
# Epoch [   24/   50] | d_loss: 0.5673 | g_loss: 1.9710
# Epoch [   24/   50] | d_loss: 0.4073 | g_loss: 2.1810
# Epoch [   24/   50] | d_loss: 0.3887 | g_loss: 1.8227
# Epoch [   24/   50] | d_loss: 2.5675 | g_loss: 3.6716
# Epoch [   24/   50] | d_loss: 0.4527 | g_loss: 2.2753
# Epoch [   24/   50] | d_loss: 0.4232 | g_loss: 3.0033
# Epoch [   24/   50] | d_loss: 0.2749 | g_loss: 2.2027
# Epoch [   24/   50] | d_loss: 0.6643 | g_loss: 1.3292
# Epoch [   24/   50] | d_loss: 0.3419 | g_loss: 2.4725
# Epoch [   24/   50] | d_loss: 0.3192 | g_loss: 3.0905
# Epoch [   24/   50] | d_loss: 0.4444 | g_loss: 3.0427
# Epoch [   24/   50] | d_loss: 0.3257 | g_loss: 2.6075
# Epoch [   24/   50] | d_loss: 0.3151 | g_loss: 2.4635
# Epoch [   24/   50] | d_loss: 0.2735 | g_loss: 2.0803
# Epoch [   25/   50] | d_loss: 0.5384 | g_loss: 3.3982
# Epoch [   25/   50] | d_loss: 0.5432 | g_loss: 1.5913
# Epoch [   25/   50] | d_loss: 0.4279 | g_loss: 1.9535
# Epoch [   25/   50] | d_loss: 0.4436 | g_loss: 3.0360
# Epoch [   25/   50] | d_loss: 1.1298 | g_loss: 1.9918
# Epoch [   25/   50] | d_loss: 0.3272 | g_loss: 2.2159
# Epoch [   25/   50] | d_loss: 0.7166 | g_loss: 2.2194
# Epoch [   25/   50] | d_loss: 0.3183 | g_loss: 3.2400
# Epoch [   25/   50] | d_loss: 0.2836 | g_loss: 2.9093
# Epoch [   25/   50] | d_loss: 0.2324 | g_loss: 1.9759
# Epoch [   25/   50] | d_loss: 0.4315 | g_loss: 3.5472
# Epoch [   25/   50] | d_loss: 0.5118 | g_loss: 1.5690
# Epoch [   25/   50] | d_loss: 0.2749 | g_loss: 2.5413
# Epoch [   25/   50] | d_loss: 0.4943 | g_loss: 1.8133
# Epoch [   25/   50] | d_loss: 0.2322 | g_loss: 2.9369
# Epoch [   25/   50] | d_loss: 0.2809 | g_loss: 2.2991
# Epoch [   25/   50] | d_loss: 0.2828 | g_loss: 2.0351
# Epoch [   25/   50] | d_loss: 0.7108 | g_loss: 3.1276
# Epoch [   25/   50] | d_loss: 0.3037 | g_loss: 2.0641
# Epoch [   25/   50] | d_loss: 0.2065 | g_loss: 3.3447
# Epoch [   25/   50] | d_loss: 0.5026 | g_loss: 4.0415
# Epoch [   25/   50] | d_loss: 0.1882 | g_loss: 2.0862
# Epoch [   25/   50] | d_loss: 0.2742 | g_loss: 3.9686
# Epoch [   25/   50] | d_loss: 0.3995 | g_loss: 2.0566
# Epoch [   25/   50] | d_loss: 0.3498 | g_loss: 2.6203
# Epoch [   25/   50] | d_loss: 0.1904 | g_loss: 3.2098
# Epoch [   25/   50] | d_loss: 0.4022 | g_loss: 2.9579
# Epoch [   25/   50] | d_loss: 0.8321 | g_loss: 1.3883
# Epoch [   25/   50] | d_loss: 0.3360 | g_loss: 3.0411
# Epoch [   26/   50] | d_loss: 0.2773 | g_loss: 3.0247
# Epoch [   26/   50] | d_loss: 0.5086 | g_loss: 2.0207
# Epoch [   26/   50] | d_loss: 0.2608 | g_loss: 2.6737
# Epoch [   26/   50] | d_loss: 0.4042 | g_loss: 2.4126
# Epoch [   26/   50] | d_loss: 0.7441 | g_loss: 4.0692
# Epoch [   26/   50] | d_loss: 0.2747 | g_loss: 3.0956
# Epoch [   26/   50] | d_loss: 0.4685 | g_loss: 2.3057
# Epoch [   26/   50] | d_loss: 0.2893 | g_loss: 3.1494
# Epoch [   26/   50] | d_loss: 0.4102 | g_loss: 1.9973
# Epoch [   26/   50] | d_loss: 0.3371 | g_loss: 3.0042
# Epoch [   26/   50] | d_loss: 0.3358 | g_loss: 2.7225
# Epoch [   26/   50] | d_loss: 0.2717 | g_loss: 2.8829
# Epoch [   26/   50] | d_loss: 0.3698 | g_loss: 2.8576
# Epoch [   26/   50] | d_loss: 0.3470 | g_loss: 1.9641
# Epoch [   26/   50] | d_loss: 0.3881 | g_loss: 1.7003
# Epoch [   26/   50] | d_loss: 0.3561 | g_loss: 3.2680
# Epoch [   26/   50] | d_loss: 0.3181 | g_loss: 3.3717
# Epoch [   26/   50] | d_loss: 0.5690 | g_loss: 0.9329
# Epoch [   26/   50] | d_loss: 0.7102 | g_loss: 2.0456
# Epoch [   26/   50] | d_loss: 0.3275 | g_loss: 1.6645
# Epoch [   26/   50] | d_loss: 0.4292 | g_loss: 2.5875
# Epoch [   26/   50] | d_loss: 0.5043 | g_loss: 2.6000
# Epoch [   26/   50] | d_loss: 0.6494 | g_loss: 1.7278
# Epoch [   26/   50] | d_loss: 1.5635 | g_loss: 3.5225
# Epoch [   26/   50] | d_loss: 0.1903 | g_loss: 3.6199
# Epoch [   26/   50] | d_loss: 0.2816 | g_loss: 2.9792
# Epoch [   26/   50] | d_loss: 0.2391 | g_loss: 2.9525
# Epoch [   26/   50] | d_loss: 0.5865 | g_loss: 4.0711
# Epoch [   26/   50] | d_loss: 0.2690 | g_loss: 2.2184
# Epoch [   27/   50] | d_loss: 2.3489 | g_loss: 6.4966
# Epoch [   27/   50] | d_loss: 0.2828 | g_loss: 2.3429
# Epoch [   27/   50] | d_loss: 0.2289 | g_loss: 2.7487
# Epoch [   27/   50] | d_loss: 0.2408 | g_loss: 2.3468
# Epoch [   27/   50] | d_loss: 0.5983 | g_loss: 1.6431
# Epoch [   27/   50] | d_loss: 0.2591 | g_loss: 3.6227
# Epoch [   27/   50] | d_loss: 0.3462 | g_loss: 2.9290
# Epoch [   27/   50] | d_loss: 0.4801 | g_loss: 2.1586
# Epoch [   27/   50] | d_loss: 0.3212 | g_loss: 2.5242
# Epoch [   27/   50] | d_loss: 0.4400 | g_loss: 2.5628
# Epoch [   27/   50] | d_loss: 0.2714 | g_loss: 2.6725
# Epoch [   27/   50] | d_loss: 0.2338 | g_loss: 2.4135
# Epoch [   27/   50] | d_loss: 0.1277 | g_loss: 2.6676
# Epoch [   27/   50] | d_loss: 1.7615 | g_loss: 0.5147
# Epoch [   27/   50] | d_loss: 0.2963 | g_loss: 3.6703
# Epoch [   27/   50] | d_loss: 0.1543 | g_loss: 4.6676
# Epoch [   27/   50] | d_loss: 0.3484 | g_loss: 2.2468
# Epoch [   27/   50] | d_loss: 1.0302 | g_loss: 4.4445
# Epoch [   27/   50] | d_loss: 0.2633 | g_loss: 2.9080
# Epoch [   27/   50] | d_loss: 0.2968 | g_loss: 3.1485
# Epoch [   27/   50] | d_loss: 0.6009 | g_loss: 1.9056
# Epoch [   27/   50] | d_loss: 0.1538 | g_loss: 3.9612
# Epoch [   27/   50] | d_loss: 0.2275 | g_loss: 2.1521
# Epoch [   27/   50] | d_loss: 0.3288 | g_loss: 2.9619
# Epoch [   27/   50] | d_loss: 0.3233 | g_loss: 2.8595
# Epoch [   27/   50] | d_loss: 0.1250 | g_loss: 3.4610
# Epoch [   27/   50] | d_loss: 0.3317 | g_loss: 3.1742
# Epoch [   27/   50] | d_loss: 0.4555 | g_loss: 2.2900
# Epoch [   27/   50] | d_loss: 1.1107 | g_loss: 3.4435
# Epoch [   28/   50] | d_loss: 4.3013 | g_loss: 7.6797
# Epoch [   28/   50] | d_loss: 0.3155 | g_loss: 4.0629
# Epoch [   28/   50] | d_loss: 0.2138 | g_loss: 3.3841
# Epoch [   28/   50] | d_loss: 0.2616 | g_loss: 2.4751
# Epoch [   28/   50] | d_loss: 0.3462 | g_loss: 3.0438
# Epoch [   28/   50] | d_loss: 0.2892 | g_loss: 2.4730
# Epoch [   28/   50] | d_loss: 0.1957 | g_loss: 3.1414
# Epoch [   28/   50] | d_loss: 0.2616 | g_loss: 3.1568
# Epoch [   28/   50] | d_loss: 0.2465 | g_loss: 1.5144
# Epoch [   28/   50] | d_loss: 0.2925 | g_loss: 1.8048
# Epoch [   28/   50] | d_loss: 0.5268 | g_loss: 2.8335
# Epoch [   28/   50] | d_loss: 0.1675 | g_loss: 2.8022
# Epoch [   28/   50] | d_loss: 0.4126 | g_loss: 3.8815
# Epoch [   28/   50] | d_loss: 0.3349 | g_loss: 3.2892
# Epoch [   28/   50] | d_loss: 0.3275 | g_loss: 2.3916
# Epoch [   28/   50] | d_loss: 0.3823 | g_loss: 2.7575
# Epoch [   28/   50] | d_loss: 0.3729 | g_loss: 4.1659
# Epoch [   28/   50] | d_loss: 0.2230 | g_loss: 2.7138
# Epoch [   28/   50] | d_loss: 0.1713 | g_loss: 2.5189
# Epoch [   28/   50] | d_loss: 0.3622 | g_loss: 2.2887
# Epoch [   28/   50] | d_loss: 0.1213 | g_loss: 3.6718
# Epoch [   28/   50] | d_loss: 0.2914 | g_loss: 3.2347
# Epoch [   28/   50] | d_loss: 7.0588 | g_loss: 0.0605
# Epoch [   28/   50] | d_loss: 0.3123 | g_loss: 3.0404
# Epoch [   28/   50] | d_loss: 0.2982 | g_loss: 3.2731
# Epoch [   28/   50] | d_loss: 0.1709 | g_loss: 3.2236
# Epoch [   28/   50] | d_loss: 0.2156 | g_loss: 2.9638
# Epoch [   28/   50] | d_loss: 0.2953 | g_loss: 2.8024
# Epoch [   28/   50] | d_loss: 0.1732 | g_loss: 3.2803
# Epoch [   29/   50] | d_loss: 0.6830 | g_loss: 3.5386
# Epoch [   29/   50] | d_loss: 0.2498 | g_loss: 2.7378
# Epoch [   29/   50] | d_loss: 0.3027 | g_loss: 3.1346
# Epoch [   29/   50] | d_loss: 0.4291 | g_loss: 2.6329
# Epoch [   29/   50] | d_loss: 0.2359 | g_loss: 2.7746
# Epoch [   29/   50] | d_loss: 0.2345 | g_loss: 3.5765
# Epoch [   29/   50] | d_loss: 0.2400 | g_loss: 3.2755
# Epoch [   29/   50] | d_loss: 0.2771 | g_loss: 2.6641
# Epoch [   29/   50] | d_loss: 0.1403 | g_loss: 3.2346
# Epoch [   29/   50] | d_loss: 0.1961 | g_loss: 3.1557
# Epoch [   29/   50] | d_loss: 0.1494 | g_loss: 3.8526
# Epoch [   29/   50] | d_loss: 0.3553 | g_loss: 4.0365
# Epoch [   29/   50] | d_loss: 0.7859 | g_loss: 1.0756
# Epoch [   29/   50] | d_loss: 0.4049 | g_loss: 3.9271
# Epoch [   29/   50] | d_loss: 0.2688 | g_loss: 1.5722
# Epoch [   29/   50] | d_loss: 0.2497 | g_loss: 3.2969
# Epoch [   29/   50] | d_loss: 0.2640 | g_loss: 2.0511
# Epoch [   29/   50] | d_loss: 0.3117 | g_loss: 2.2850
# Epoch [   29/   50] | d_loss: 0.4723 | g_loss: 2.2714
# Epoch [   29/   50] | d_loss: 0.2687 | g_loss: 3.2164
# Epoch [   29/   50] | d_loss: 0.1303 | g_loss: 3.6148
# Epoch [   29/   50] | d_loss: 0.3555 | g_loss: 2.9825
# Epoch [   29/   50] | d_loss: 0.3270 | g_loss: 3.2629
# Epoch [   29/   50] | d_loss: 0.1459 | g_loss: 2.7673
# Epoch [   29/   50] | d_loss: 0.5501 | g_loss: 3.2541
# Epoch [   29/   50] | d_loss: 0.3218 | g_loss: 3.3614
# Epoch [   29/   50] | d_loss: 0.2732 | g_loss: 2.6455
# Epoch [   29/   50] | d_loss: 0.2683 | g_loss: 2.6932
# Epoch [   29/   50] | d_loss: 0.2861 | g_loss: 2.7362
# Epoch [   30/   50] | d_loss: 0.4765 | g_loss: 3.4038
# Epoch [   30/   50] | d_loss: 0.2864 | g_loss: 3.0178
# Epoch [   30/   50] | d_loss: 0.2581 | g_loss: 2.5840
# Epoch [   30/   50] | d_loss: 0.2024 | g_loss: 3.4624
# Epoch [   30/   50] | d_loss: 0.3459 | g_loss: 1.5205
# Epoch [   30/   50] | d_loss: 0.1916 | g_loss: 2.8015
# Epoch [   30/   50] | d_loss: 0.1431 | g_loss: 4.4401
# Epoch [   30/   50] | d_loss: 0.2062 | g_loss: 4.4918
# Epoch [   30/   50] | d_loss: 0.1886 | g_loss: 2.2997
# Epoch [   30/   50] | d_loss: 0.3428 | g_loss: 2.2929
# Epoch [   30/   50] | d_loss: 0.2255 | g_loss: 3.1781
# Epoch [   30/   50] | d_loss: 0.1660 | g_loss: 3.2892
# Epoch [   30/   50] | d_loss: 0.2453 | g_loss: 2.8215
# Epoch [   30/   50] | d_loss: 0.4084 | g_loss: 1.8415
# Epoch [   30/   50] | d_loss: 0.2935 | g_loss: 4.2021
# Epoch [   30/   50] | d_loss: 0.2719 | g_loss: 2.3130
# Epoch [   30/   50] | d_loss: 0.3825 | g_loss: 2.5194
# Epoch [   30/   50] | d_loss: 0.3082 | g_loss: 2.8114
# Epoch [   30/   50] | d_loss: 0.9080 | g_loss: 1.5618
# Epoch [   30/   50] | d_loss: 0.2294 | g_loss: 2.1256
# Epoch [   30/   50] | d_loss: 0.1454 | g_loss: 4.8622
# Epoch [   30/   50] | d_loss: 0.2074 | g_loss: 2.0611
# Epoch [   30/   50] | d_loss: 1.5803 | g_loss: 7.7062
# Epoch [   30/   50] | d_loss: 0.3508 | g_loss: 2.6966
# Epoch [   30/   50] | d_loss: 1.0161 | g_loss: 1.2994
# Epoch [   30/   50] | d_loss: 0.3143 | g_loss: 2.8301
# Epoch [   30/   50] | d_loss: 0.3606 | g_loss: 2.2760
# Epoch [   30/   50] | d_loss: 0.5236 | g_loss: 4.2606
# Epoch [   30/   50] | d_loss: 0.1925 | g_loss: 3.5669
# Epoch [   31/   50] | d_loss: 0.2809 | g_loss: 3.3277
# Epoch [   31/   50] | d_loss: 0.2222 | g_loss: 2.5399
# Epoch [   31/   50] | d_loss: 0.1655 | g_loss: 3.3388
# Epoch [   31/   50] | d_loss: 0.2289 | g_loss: 2.5934
# Epoch [   31/   50] | d_loss: 0.3450 | g_loss: 4.0242
# Epoch [   31/   50] | d_loss: 0.2017 | g_loss: 3.6770
# Epoch [   31/   50] | d_loss: 0.2386 | g_loss: 3.9466
# Epoch [   31/   50] | d_loss: 0.2273 | g_loss: 3.8045
# Epoch [   31/   50] | d_loss: 0.4212 | g_loss: 3.8220
# Epoch [   31/   50] | d_loss: 0.2461 | g_loss: 3.0863
# Epoch [   31/   50] | d_loss: 0.3649 | g_loss: 3.4502
# Epoch [   31/   50] | d_loss: 0.2087 | g_loss: 2.6462
# Epoch [   31/   50] | d_loss: 0.3079 | g_loss: 3.4942
# Epoch [   31/   50] | d_loss: 0.2627 | g_loss: 3.6165
# Epoch [   31/   50] | d_loss: 0.2755 | g_loss: 2.4700
# Epoch [   31/   50] | d_loss: 0.0984 | g_loss: 2.2188
# Epoch [   31/   50] | d_loss: 0.3551 | g_loss: 2.9523
# Epoch [   31/   50] | d_loss: 0.4869 | g_loss: 3.4306
# ...
# Epoch [   40/   50] | d_loss: 0.0797 | g_loss: 4.4077
# Epoch [   40/   50] | d_loss: 0.1616 | g_loss: 3.1307
# Epoch [   40/   50] | d_loss: 0.5106 | g_loss: 6.5046
# Epoch [   40/   50] | d_loss: 2.1072 | g_loss: 0.4267
# Epoch [   40/   50] | d_loss: 0.5932 | g_loss: 1.7490
# Epoch [   40/   50] | d_loss: 0.1936 | g_loss: 3.0365
# Epoch [   41/   50] | d_loss: 0.4143 | g_loss: 5.2714
# Epoch [   41/   50] | d_loss: 0.2390 | g_loss: 2.9722
# Epoch [   41/   50] | d_loss: 0.1856 | g_loss: 2.9401
# Epoch [   41/   50] | d_loss: 0.1632 | g_loss: 3.4876
# Epoch [   41/   50] | d_loss: 0.7884 | g_loss: 5.0364
# Epoch [   41/   50] | d_loss: 0.1350 | g_loss: 3.5997
# Epoch [   41/   50] | d_loss: 0.1087 | g_loss: 3.5253
# Epoch [   41/   50] | d_loss: 0.4009 | g_loss: 3.3646
# Epoch [   41/   50] | d_loss: 0.1550 | g_loss: 3.6077
# Epoch [   41/   50] | d_loss: 0.0651 | g_loss: 4.2887
# Epoch [   41/   50] | d_loss: 0.2323 | g_loss: 3.8642
# Epoch [   41/   50] | d_loss: 0.2168 | g_loss: 3.4413
# Epoch [   41/   50] | d_loss: 0.1322 | g_loss: 3.5415
# Epoch [   41/   50] | d_loss: 0.1457 | g_loss: 4.3395
# Epoch [   41/   50] | d_loss: 0.1278 | g_loss: 3.8435
# Epoch [   41/   50] | d_loss: 0.2974 | g_loss: 2.6011
# Epoch [   41/   50] | d_loss: 0.0671 | g_loss: 4.5474
# Epoch [   41/   50] | d_loss: 0.2819 | g_loss: 5.0590
# Epoch [   41/   50] | d_loss: 0.8169 | g_loss: 2.9486
# Epoch [   41/   50] | d_loss: 0.0972 | g_loss: 4.2576
# Epoch [   41/   50] | d_loss: 0.0627 | g_loss: 2.7886
# Epoch [   41/   50] | d_loss: 0.1059 | g_loss: 3.2772
# Epoch [   41/   50] | d_loss: 0.1219 | g_loss: 3.5006
# Epoch [   41/   50] | d_loss: 0.3663 | g_loss: 2.8749
# Epoch [   41/   50] | d_loss: 0.2253 | g_loss: 3.9592
# Epoch [   41/   50] | d_loss: 0.7126 | g_loss: 1.8582
# Epoch [   41/   50] | d_loss: 0.2050 | g_loss: 1.9148
# Epoch [   41/   50] | d_loss: 0.3097 | g_loss: 2.9681
# Epoch [   41/   50] | d_loss: 0.0832 | g_loss: 2.8288
# Epoch [   42/   50] | d_loss: 0.1108 | g_loss: 3.5130
# Epoch [   42/   50] | d_loss: 0.1393 | g_loss: 4.3066
# Epoch [   42/   50] | d_loss: 0.1788 | g_loss: 3.8638
# Epoch [   42/   50] | d_loss: 0.1197 | g_loss: 4.5777
# Epoch [   42/   50] | d_loss: 0.1775 | g_loss: 2.8341
# Epoch [   42/   50] | d_loss: 0.1644 | g_loss: 3.3022
# Epoch [   42/   50] | d_loss: 0.2075 | g_loss: 2.8652
# Epoch [   42/   50] | d_loss: 0.1735 | g_loss: 4.3915
# Epoch [   42/   50] | d_loss: 0.1565 | g_loss: 3.8847
# Epoch [   42/   50] | d_loss: 0.1009 | g_loss: 3.7371
# Epoch [   42/   50] | d_loss: 0.0763 | g_loss: 4.4462
# Epoch [   42/   50] | d_loss: 0.0885 | g_loss: 4.8789
# Epoch [   42/   50] | d_loss: 0.2115 | g_loss: 3.5765
# Epoch [   42/   50] | d_loss: 0.1194 | g_loss: 4.0570
# Epoch [   42/   50] | d_loss: 1.1380 | g_loss: 0.0575
# Epoch [   42/   50] | d_loss: 0.3804 | g_loss: 5.0454
# Epoch [   42/   50] | d_loss: 0.1540 | g_loss: 4.4268
# Epoch [   42/   50] | d_loss: 0.1670 | g_loss: 4.7134
# Epoch [   42/   50] | d_loss: 0.0417 | g_loss: 5.0743
# Epoch [   42/   50] | d_loss: 0.0876 | g_loss: 5.2440
# Epoch [   42/   50] | d_loss: 0.1140 | g_loss: 4.1882
# Epoch [   42/   50] | d_loss: 0.1335 | g_loss: 4.5470
# Epoch [   42/   50] | d_loss: 0.1296 | g_loss: 3.6636
# Epoch [   42/   50] | d_loss: 0.1443 | g_loss: 2.7595
# Epoch [   42/   50] | d_loss: 0.0798 | g_loss: 5.6303
# Epoch [   42/   50] | d_loss: 0.8554 | g_loss: 6.0138
# Epoch [   42/   50] | d_loss: 0.4642 | g_loss: 2.8942
# Epoch [   42/   50] | d_loss: 0.1818 | g_loss: 3.8793
# Epoch [   42/   50] | d_loss: 0.1315 | g_loss: 2.6105
# Epoch [   43/   50] | d_loss: 0.2602 | g_loss: 5.0311
# Epoch [   43/   50] | d_loss: 0.2672 | g_loss: 2.4448
# Epoch [   43/   50] | d_loss: 0.1003 | g_loss: 3.2411
# Epoch [   43/   50] | d_loss: 0.2804 | g_loss: 4.9119
# Epoch [   43/   50] | d_loss: 0.0913 | g_loss: 4.6378
# Epoch [   43/   50] | d_loss: 0.1952 | g_loss: 3.2636
# Epoch [   43/   50] | d_loss: 0.0828 | g_loss: 4.5094
# Epoch [   43/   50] | d_loss: 0.0920 | g_loss: 3.2026
# Epoch [   43/   50] | d_loss: 0.1946 | g_loss: 2.1736
# Epoch [   43/   50] | d_loss: 0.1380 | g_loss: 3.6181
# Epoch [   43/   50] | d_loss: 0.0958 | g_loss: 4.1452
# Epoch [   43/   50] | d_loss: 0.0964 | g_loss: 4.4457
# Epoch [   43/   50] | d_loss: 0.0937 | g_loss: 3.2493
# Epoch [   43/   50] | d_loss: 0.1599 | g_loss: 3.8451
# Epoch [   43/   50] | d_loss: 3.1620 | g_loss: 3.1654
# Epoch [   43/   50] | d_loss: 1.2101 | g_loss: 1.3720
# Epoch [   43/   50] | d_loss: 0.1291 | g_loss: 3.8071
# Epoch [   43/   50] | d_loss: 0.1802 | g_loss: 3.0121
# Epoch [   43/   50] | d_loss: 0.2269 | g_loss: 2.4952
# Epoch [   43/   50] | d_loss: 0.1223 | g_loss: 4.1504
# Epoch [   43/   50] | d_loss: 0.0687 | g_loss: 4.5519
# Epoch [   43/   50] | d_loss: 0.1359 | g_loss: 3.9382
# Epoch [   43/   50] | d_loss: 0.0481 | g_loss: 4.8158
# Epoch [   43/   50] | d_loss: 0.1972 | g_loss: 4.0209
# Epoch [   43/   50] | d_loss: 0.1251 | g_loss: 3.0038
# Epoch [   43/   50] | d_loss: 0.4281 | g_loss: 4.5055
# Epoch [   43/   50] | d_loss: 0.1198 | g_loss: 3.2709
# Epoch [   43/   50] | d_loss: 0.1986 | g_loss: 3.1996
# Epoch [   43/   50] | d_loss: 0.1791 | g_loss: 2.3658
# Epoch [   44/   50] | d_loss: 0.2005 | g_loss: 4.0957
# Epoch [   44/   50] | d_loss: 0.1008 | g_loss: 4.6094
# Epoch [   44/   50] | d_loss: 0.3772 | g_loss: 2.6830
# Epoch [   44/   50] | d_loss: 0.1070 | g_loss: 3.0376
# Epoch [   44/   50] | d_loss: 0.1424 | g_loss: 3.1908
# Epoch [   44/   50] | d_loss: 0.8188 | g_loss: 6.5605
# Epoch [   44/   50] | d_loss: 0.1820 | g_loss: 3.2038
# Epoch [   44/   50] | d_loss: 0.1629 | g_loss: 3.7093
# Epoch [   44/   50] | d_loss: 0.0979 | g_loss: 4.0120
# Epoch [   44/   50] | d_loss: 0.0967 | g_loss: 3.6419
# Epoch [   44/   50] | d_loss: 0.1164 | g_loss: 4.4444
# Epoch [   44/   50] | d_loss: 0.0697 | g_loss: 3.9318
# Epoch [   44/   50] | d_loss: 0.1951 | g_loss: 5.1216
# Epoch [   44/   50] | d_loss: 0.1128 | g_loss: 3.9136
# Epoch [   44/   50] | d_loss: 0.0793 | g_loss: 4.9576
# Epoch [   44/   50] | d_loss: 0.1017 | g_loss: 4.8392
# Epoch [   44/   50] | d_loss: 0.3005 | g_loss: 1.7036
# Epoch [   44/   50] | d_loss: 0.0830 | g_loss: 3.5423
# Epoch [   44/   50] | d_loss: 1.1153 | g_loss: 1.3635
# Epoch [   44/   50] | d_loss: 0.1162 | g_loss: 4.2622
# Epoch [   44/   50] | d_loss: 0.1273 | g_loss: 3.9147
# Epoch [   44/   50] | d_loss: 0.2146 | g_loss: 4.7221
# Epoch [   44/   50] | d_loss: 0.0811 | g_loss: 4.4970
# Epoch [   44/   50] | d_loss: 0.1250 | g_loss: 3.0314
# Epoch [   44/   50] | d_loss: 0.6134 | g_loss: 5.3706
# Epoch [   44/   50] | d_loss: 0.1956 | g_loss: 4.6036
# Epoch [   44/   50] | d_loss: 0.2277 | g_loss: 3.9430
# Epoch [   44/   50] | d_loss: 0.1245 | g_loss: 3.1229
# Epoch [   44/   50] | d_loss: 0.5160 | g_loss: 5.5691
# Epoch [   45/   50] | d_loss: 0.2065 | g_loss: 4.9005
# Epoch [   45/   50] | d_loss: 0.0781 | g_loss: 3.9392
# Epoch [   45/   50] | d_loss: 0.1506 | g_loss: 5.0335
# Epoch [   45/   50] | d_loss: 0.0874 | g_loss: 4.5453
# Epoch [   45/   50] | d_loss: 0.0711 | g_loss: 4.2119
# Epoch [   45/   50] | d_loss: 0.1978 | g_loss: 3.3635
# Epoch [   45/   50] | d_loss: 0.1103 | g_loss: 4.6602
# Epoch [   45/   50] | d_loss: 0.0687 | g_loss: 4.5992
# Epoch [   45/   50] | d_loss: 0.2930 | g_loss: 2.8675
# Epoch [   45/   50] | d_loss: 0.8464 | g_loss: 2.1476
# Epoch [   45/   50] | d_loss: 0.1283 | g_loss: 3.9118
# Epoch [   45/   50] | d_loss: 0.0816 | g_loss: 4.8512
# Epoch [   45/   50] | d_loss: 0.0687 | g_loss: 3.9658
# Epoch [   45/   50] | d_loss: 0.1261 | g_loss: 5.3173
# Epoch [   45/   50] | d_loss: 0.1217 | g_loss: 3.8177
# Epoch [   45/   50] | d_loss: 0.1141 | g_loss: 5.2131
# Epoch [   45/   50] | d_loss: 0.1284 | g_loss: 3.5194
# Epoch [   45/   50] | d_loss: 0.1108 | g_loss: 3.3388
# Epoch [   45/   50] | d_loss: 0.1289 | g_loss: 3.7198
# Epoch [   45/   50] | d_loss: 0.1263 | g_loss: 4.8532
# Epoch [   45/   50] | d_loss: 0.0627 | g_loss: 3.6255
# Epoch [   45/   50] | d_loss: 0.6705 | g_loss: 5.8141
# Epoch [   45/   50] | d_loss: 0.6378 | g_loss: 4.9194
# Epoch [   45/   50] | d_loss: 0.1223 | g_loss: 5.6347
# Epoch [   45/   50] | d_loss: 0.2287 | g_loss: 4.6477
# Epoch [   45/   50] | d_loss: 0.0532 | g_loss: 4.3924
# Epoch [   45/   50] | d_loss: 0.0816 | g_loss: 4.7072
# Epoch [   45/   50] | d_loss: 0.1079 | g_loss: 3.5437
# Epoch [   45/   50] | d_loss: 0.0703 | g_loss: 4.7204
# Epoch [   46/   50] | d_loss: 0.2176 | g_loss: 2.6186
# Epoch [   46/   50] | d_loss: 0.1127 | g_loss: 4.1605
# Epoch [   46/   50] | d_loss: 0.0757 | g_loss: 2.8990
# Epoch [   46/   50] | d_loss: 0.1237 | g_loss: 5.0134
# Epoch [   46/   50] | d_loss: 0.2061 | g_loss: 4.4021
# Epoch [   46/   50] | d_loss: 0.0997 | g_loss: 3.8705
# Epoch [   46/   50] | d_loss: 0.0803 | g_loss: 4.0903
# Epoch [   46/   50] | d_loss: 0.0668 | g_loss: 4.6081
# Epoch [   46/   50] | d_loss: 0.0821 | g_loss: 4.9390
# Epoch [   46/   50] | d_loss: 2.1380 | g_loss: 0.0638
# Epoch [   46/   50] | d_loss: 0.2014 | g_loss: 3.5616
# Epoch [   46/   50] | d_loss: 0.0770 | g_loss: 4.1645
# Epoch [   46/   50] | d_loss: 0.0783 | g_loss: 3.5711
# Epoch [   46/   50] | d_loss: 0.1616 | g_loss: 3.4055
# Epoch [   46/   50] | d_loss: 0.1947 | g_loss: 3.7807
# Epoch [   46/   50] | d_loss: 0.0983 | g_loss: 4.4763
# Epoch [   46/   50] | d_loss: 0.1755 | g_loss: 2.2792
# Epoch [   46/   50] | d_loss: 0.1472 | g_loss: 3.0129
# Epoch [   46/   50] | d_loss: 0.1411 | g_loss: 4.9443
# Epoch [   46/   50] | d_loss: 0.1117 | g_loss: 4.2285
# Epoch [   46/   50] | d_loss: 0.0926 | g_loss: 4.5536
# Epoch [   46/   50] | d_loss: 0.1704 | g_loss: 4.0829
# Epoch [   46/   50] | d_loss: 0.0747 | g_loss: 5.0085
# Epoch [   46/   50] | d_loss: 0.1175 | g_loss: 4.1786
# Epoch [   46/   50] | d_loss: 0.1446 | g_loss: 4.8650
# Epoch [   46/   50] | d_loss: 0.2262 | g_loss: 4.6731
# Epoch [   46/   50] | d_loss: 0.1720 | g_loss: 3.2492
# Epoch [   46/   50] | d_loss: 0.1328 | g_loss: 4.7460
# Epoch [   46/   50] | d_loss: 0.2056 | g_loss: 3.7658
# Epoch [   47/   50] | d_loss: 0.0790 | g_loss: 4.3584
# Epoch [   47/   50] | d_loss: 0.0986 | g_loss: 4.0631
# Epoch [   47/   50] | d_loss: 0.1123 | g_loss: 4.0245
# Epoch [   47/   50] | d_loss: 0.0693 | g_loss: 4.4302
# Epoch [   47/   50] | d_loss: 0.0622 | g_loss: 3.2180
# Epoch [   47/   50] | d_loss: 0.0320 | g_loss: 3.8962
# Epoch [   47/   50] | d_loss: 0.0592 | g_loss: 4.8937
# Epoch [   47/   50] | d_loss: 0.3318 | g_loss: 3.1433
# Epoch [   47/   50] | d_loss: 0.1909 | g_loss: 4.2205
# Epoch [   47/   50] | d_loss: 1.1808 | g_loss: 7.7939
# Epoch [   47/   50] | d_loss: 0.1377 | g_loss: 3.7343
# Epoch [   47/   50] | d_loss: 0.1269 | g_loss: 2.9931
# Epoch [   47/   50] | d_loss: 0.0514 | g_loss: 4.2536
# Epoch [   47/   50] | d_loss: 0.0888 | g_loss: 4.5630
# Epoch [   47/   50] | d_loss: 0.1410 | g_loss: 3.3926
# Epoch [   47/   50] | d_loss: 0.1065 | g_loss: 3.6689
# Epoch [   47/   50] | d_loss: 0.1356 | g_loss: 4.5513
# Epoch [   47/   50] | d_loss: 0.2070 | g_loss: 6.4016
# Epoch [   47/   50] | d_loss: 2.0113 | g_loss: 6.8800
# Epoch [   47/   50] | d_loss: 0.0679 | g_loss: 3.5292
# Epoch [   47/   50] | d_loss: 0.1672 | g_loss: 3.9415
# Epoch [   47/   50] | d_loss: 0.2708 | g_loss: 2.6116
# Epoch [   47/   50] | d_loss: 0.0877 | g_loss: 3.4460
# Epoch [   47/   50] | d_loss: 0.3201 | g_loss: 4.3450
# Epoch [   47/   50] | d_loss: 0.1195 | g_loss: 3.1845
# Epoch [   47/   50] | d_loss: 0.1630 | g_loss: 4.1727
# Epoch [   47/   50] | d_loss: 0.1039 | g_loss: 4.0250
# Epoch [   47/   50] | d_loss: 0.0801 | g_loss: 5.2597
# Epoch [   47/   50] | d_loss: 0.1772 | g_loss: 2.3383
# Epoch [   48/   50] | d_loss: 0.2763 | g_loss: 4.8252
# Epoch [   48/   50] | d_loss: 0.0800 | g_loss: 4.5133
# Epoch [   48/   50] | d_loss: 0.4068 | g_loss: 7.5990
# Epoch [   48/   50] | d_loss: 0.1490 | g_loss: 5.0206
# Epoch [   48/   50] | d_loss: 0.0737 | g_loss: 5.2054
# Epoch [   48/   50] | d_loss: 0.0984 | g_loss: 4.5166
# Epoch [   48/   50] | d_loss: 0.0916 | g_loss: 5.1199
# Epoch [   48/   50] | d_loss: 0.0415 | g_loss: 4.1951
# Epoch [   48/   50] | d_loss: 0.2478 | g_loss: 4.1542
# Epoch [   48/   50] | d_loss: 0.1262 | g_loss: 3.3805
# Epoch [   48/   50] | d_loss: 0.1228 | g_loss: 3.4868
# Epoch [   48/   50] | d_loss: 2.4211 | g_loss: 8.6771
# Epoch [   48/   50] | d_loss: 0.1301 | g_loss: 3.5599
# Epoch [   48/   50] | d_loss: 0.0896 | g_loss: 4.3928
# Epoch [   48/   50] | d_loss: 0.1799 | g_loss: 2.9825
# Epoch [   48/   50] | d_loss: 0.2624 | g_loss: 4.1939
# Epoch [   48/   50] | d_loss: 0.1292 | g_loss: 4.3229
# Epoch [   48/   50] | d_loss: 0.0772 | g_loss: 5.2328
# Epoch [   48/   50] | d_loss: 0.0606 | g_loss: 5.4725
# Epoch [   48/   50] | d_loss: 0.1411 | g_loss: 4.7072
# Epoch [   48/   50] | d_loss: 0.0527 | g_loss: 3.8834
# Epoch [   48/   50] | d_loss: 1.0960 | g_loss: 0.9063
# Epoch [   48/   50] | d_loss: 0.2347 | g_loss: 3.9009
# Epoch [   48/   50] | d_loss: 0.2697 | g_loss: 4.1458
# Epoch [   48/   50] | d_loss: 0.0570 | g_loss: 4.0736
# Epoch [   48/   50] | d_loss: 0.1236 | g_loss: 4.5340
# Epoch [   48/   50] | d_loss: 0.0419 | g_loss: 6.2744
# Epoch [   48/   50] | d_loss: 0.1249 | g_loss: 3.4627
# Epoch [   48/   50] | d_loss: 0.0742 | g_loss: 4.9751
# Epoch [   49/   50] | d_loss: 0.0832 | g_loss: 4.7784
# Epoch [   49/   50] | d_loss: 0.2114 | g_loss: 5.6608
# Epoch [   49/   50] | d_loss: 0.1004 | g_loss: 5.6341
# Epoch [   49/   50] | d_loss: 0.2024 | g_loss: 3.1589
# Epoch [   49/   50] | d_loss: 0.1307 | g_loss: 3.6136
# Epoch [   49/   50] | d_loss: 0.2720 | g_loss: 5.9076
# Epoch [   49/   50] | d_loss: 0.0994 | g_loss: 5.8716
# Epoch [   49/   50] | d_loss: 0.5573 | g_loss: 4.0162
# Epoch [   49/   50] | d_loss: 0.1679 | g_loss: 4.6713
# Epoch [   49/   50] | d_loss: 0.0643 | g_loss: 3.9105
# Epoch [   49/   50] | d_loss: 0.0788 | g_loss: 4.9413
# Epoch [   49/   50] | d_loss: 0.1640 | g_loss: 3.8571
# Epoch [   49/   50] | d_loss: 0.1100 | g_loss: 4.5549
# Epoch [   49/   50] | d_loss: 0.2060 | g_loss: 4.2662
# Epoch [   49/   50] | d_loss: 0.1216 | g_loss: 3.6927
# Epoch [   49/   50] | d_loss: 0.1345 | g_loss: 5.6749
# Epoch [   49/   50] | d_loss: 0.3984 | g_loss: 4.1476
# Epoch [   49/   50] | d_loss: 0.1068 | g_loss: 4.6025
# Epoch [   49/   50] | d_loss: 0.0516 | g_loss: 5.1183
# Epoch [   49/   50] | d_loss: 0.1308 | g_loss: 4.0513
# Epoch [   49/   50] | d_loss: 0.0525 | g_loss: 4.2776
# Epoch [   49/   50] | d_loss: 0.2012 | g_loss: 3.8162
# Epoch [   49/   50] | d_loss: 0.1871 | g_loss: 5.5930
# Epoch [   49/   50] | d_loss: 0.0633 | g_loss: 4.7737
# Epoch [   49/   50] | d_loss: 0.8087 | g_loss: 0.7344
# Epoch [   49/   50] | d_loss: 0.1835 | g_loss: 3.3731
# Epoch [   49/   50] | d_loss: 0.1302 | g_loss: 3.0206
# Epoch [   49/   50] | d_loss: 0.1126 | g_loss: 4.4747
# Epoch [   49/   50] | d_loss: 0.0796 | g_loss: 4.3369
# Epoch [   50/   50] | d_loss: 0.3528 | g_loss: 6.2107
# Epoch [   50/   50] | d_loss: 0.0332 | g_loss: 5.4036
# Epoch [   50/   50] | d_loss: 0.0655 | g_loss: 4.0443
# Epoch [   50/   50] | d_loss: 0.0366 | g_loss: 3.4062
# Epoch [   50/   50] | d_loss: 0.1477 | g_loss: 4.3363
# Epoch [   50/   50] | d_loss: 0.0922 | g_loss: 4.6261
# Epoch [   50/   50] | d_loss: 0.0566 | g_loss: 5.5911
# Epoch [   50/   50] | d_loss: 0.1702 | g_loss: 4.7761
# Epoch [   50/   50] | d_loss: 0.0535 | g_loss: 5.3583
# Epoch [   50/   50] | d_loss: 0.0956 | g_loss: 4.9935
# Epoch [   50/   50] | d_loss: 0.1273 | g_loss: 4.7536
# Epoch [   50/   50] | d_loss: 0.1083 | g_loss: 3.8649
# Epoch [   50/   50] | d_loss: 0.1089 | g_loss: 4.2862
# Epoch [   50/   50] | d_loss: 0.0566 | g_loss: 4.3057
# Epoch [   50/   50] | d_loss: 0.1682 | g_loss: 4.7309
# Epoch [   50/   50] | d_loss: 0.0739 | g_loss: 3.0042
# Epoch [   50/   50] | d_loss: 0.3220 | g_loss: 5.1128
# Epoch [   50/   50] | d_loss: 0.0987 | g_loss: 4.7238
# Epoch [   50/   50] | d_loss: 0.1268 | g_loss: 4.5763
# Epoch [   50/   50] | d_loss: 0.0830 | g_loss: 5.2354
# Epoch [   50/   50] | d_loss: 0.0567 | g_loss: 6.0422
# Epoch [   50/   50] | d_loss: 0.0739 | g_loss: 5.6408
# Epoch [   50/   50] | d_loss: 0.0369 | g_loss: 3.8021
# Epoch [   50/   50] | d_loss: 0.1062 | g_loss: 4.2282
# Epoch [   50/   50] | d_loss: 0.0552 | g_loss: 3.7292
# Epoch [   50/   50] | d_loss: 0.0347 | g_loss: 5.0559
# Epoch [   50/   50] | d_loss: 0.0751 | g_loss: 3.8732
# Epoch [   50/   50] | d_loss: 0.0553 | g_loss: 5.1022
# Epoch [   50/   50] | d_loss: 0.0305 | g_loss: 4.7407

# %% [markdown]
# ## Training loss
#
# Plot the training losses for the generator and discriminator, recorded after each epoch.

# %%
fig, ax = plt.subplots()
losses = np.array(losses)
plt.plot(losses.T[0], label='Discriminator', alpha=0.5)
plt.plot(losses.T[1], label='Generator', alpha=0.5)
plt.title("Training Losses")
plt.legend()

# %% [markdown]
# ## Generator samples from training
#
# View samples of images from the generator, and answer a question about the strengths and weaknesses of your trained models.

# %%
# helper function for viewing a list of passed in sample images
def view_samples(epoch, samples):
    fig, axes = plt.subplots(figsize=(16,4), nrows=2, ncols=8, sharey=True, sharex=True)
    for ax, img in zip(axes.flatten(), samples[epoch]):
        img = img.detach().cpu().numpy()
        img = np.transpose(img, (1, 2, 0))
        img = ((img + 1)*255 / (2)).astype(np.uint8)
        ax.xaxis.set_visible(False)
        ax.yaxis.set_visible(False)
        im = ax.imshow(img.reshape((32,32,3)))

# %%
# Load samples from generator, taken while training
with open('train_samples.pkl', 'rb') as f:
    samples = pkl.load(f)

# %%
_ = view_samples(-1, samples)

# %% [markdown]
# ### Question: What do you notice about your generated samples and how might you improve this model?
# When you answer this question, consider the following factors:
# * The dataset is biased; it is made of "celebrity" faces that are mostly white
# * Model size; larger models have the opportunity to learn more features in a data feature space
# * Optimization strategy; optimizers and number of epochs affect your final result

# %% [markdown]
# **Answer:**
#
# * The faces are blured and Facial features aren't clear (images are creepy)
# * We might improve this by increasing number of epochs, addind droup out or use more layers and changing Hyperparameters till get beter results.

# %% [markdown]
# ### Submitting This Project
# When submitting this project, make sure to run all the cells before saving the notebook. Save the notebook file as "dlnd_face_generation.ipynb" and save it as a HTML file under "File" -> "Download as". Include the "problem_unittests.py" files in your submission.
